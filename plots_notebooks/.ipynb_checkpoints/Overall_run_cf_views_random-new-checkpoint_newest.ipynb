# %% [markdown]
# # an Overall code for CF and head views analysis for all identities and images (30 run for small ids)

# %% [markdown]
# imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from pathlib import Path
import openpyxl
import os
import re
# import ggplot
from openpyxl import load_workbook
import xlsxwriter

# %% [markdown]
# parameters

# %% [markdown]
# experiments_folder: the folder with all the experiments we want to plot and make csvs for
#
# regex: the text we take from logs in each results to extract the threshold
#
# plot_kwards: the args for the results plot
#
# save..: if we want to save the plot/csv data of the results
#
# plot folder:dest path to save the plots
#
# mean_std_folder: dest path to csv data

# %%
# for remote computer:
experiments_folder = Path('/home/administrator/experiments/all_ids/500_ids')
# experiments_folder = Path('/home/administrator/experiments/frontal_vs_variable')
regex =' (.*) threshold\\nlayer\s*\\n(\d*)(\s+)(\d*.\d*)(\s+)(\d*.\d*)\\n(\d*)(\s+)(\d*.\d*)(\s+)(\d*.\d*)\\n(\d*)(\s+)(\d*.\d*)(\s+)(\d*.\d*)'
plot_kwargs={'grid':True,'figsize':(20,8), 'fontsize':12}
save_views_plot = 0
save_cf_plot = 0
save_views_csv = 0
save_cf_csv = 0
save_mean_views_csv = 0
save_mean_cf_csv = 0
save_std_views_csv = 0
save_std_cf_csv = 0
save_se_views_csv = 0
save_se_cf_csv = 0
mean_std_folder=''
plots_folder = '/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/'
# plots_folder = '/home/administrator/plot_results/frontal_vs_variable/'
mean_folder_views='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/mean/views/'
std_folder_views='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/std/views/'
se_folder_views='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/se/views/'
mean_folder_cf='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/mean/cf/'
std_folder_cf='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/std/cf/'
se_folder_cf='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/se/cf/'

csv_list=[]
add_to_title = 'gaus_2'
excel_title = '500_ids'

# %%
#for remote computer:
experiments_folder = Path('/home/administrator/experiments/all_ids/500_ids')
experiment_file = Path('/home/ssd_storage/experiments/MR/vggtested/results/cf_vi/cf_vi_vggface_trained_2_5_ids.csv')
# experiments_folder = Path('/home/administrator/experiments/frontal_vs_variable')
regex =' (.*) threshold\\nlayer\s*\\n(\d*)(\s+)(\d*.\d*)(\s+)(\d*.\d*)\\n(\d*)(\s+)(\d*.\d*)(\s+)(\d*.\d*)\\n(\d*)(\s+)(\d*.\d*)(\s+)(\d*.\d*)'
plot_kwargs={'grid':True,'figsize':(20,8), 'fontsize':12}
save_views_plot = 0
save_cf_plot = 0
save_views_csv = 0
save_cf_csv = 0
save_mean_views_csv = 0
save_mean_cf_csv = 0
save_std_views_csv = 0
save_std_cf_csv = 0
save_se_views_csv = 0
save_se_cf_csv = 0
mean_std_folder=''
plots_folder = '/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/'
# plots_folder = '/home/administrator/plot_results/frontal_vs_variable/'
mean_folder_views='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/mean/views/'
std_folder_views='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/std/views/'
se_folder_views='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/se/views/'
mean_folder_cf='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/mean/cf/'
std_folder_cf='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/std/cf/'
se_folder_cf='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/se/cf/'

csv_list=[]
add_to_title = 'gaus_2'
excel_title = '500_ids'

# %%
# #for local computer:
# experiments_folder = Path(r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\50_10_ids_50_20_10_5_2_imgs')
# regex =' (.*) threshold\\nlayer\s*\\n(\d*)(\s+)(\d*.\d*)(\s+)(\d*.\d*)\\n(\d*)(\s+)(\d*.\d*)(\s+)(\d*.\d*)\\n(\d*)(\s+)(\d*.\d*)(\s+)(\d*.\d*)'
# plot_kwargs={'grid':True,'figsize':(20,8), 'fontsize':12}
# save_views_plot = 0
# save_cf_plot = 0
# save_views_csv = 0
# save_cf_csv = 0
# save_mean_views_csv = 0
# save_mean_cf_csv = 0
# save_std_views_csv = 0
# save_std_cf_csv = 0
# save_se_views_csv = 0
# save_se_cf_csv = 0
# mean_std_folder=''
# plots_folder = r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\results'
# mean_folder_views= r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\results\mean\views/'
# std_folder_views= r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\results\std\views/'
# se_folder_views= r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\results\se/views/'
# mean_folder_cf= r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\results/mean/cf/'
# std_folder_cf= r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\results/std/cf/'
# se_folder_cf= r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\results/se/cf/'

# csv_list=[]
# # add_to_title = 'gaus_2'
# # excel_title = '500_ids'

# %% [markdown]
# make the csvs list

# %%
# for experiment in experiments_folder.iterdir():
#     print(experiment)
#     csv_list.append(Path(experiment))
# print(csv_list)
csv_list.append(Path(experiment_file))
print(csv_list) #should be only one?
# Out:
# [PosixPath('/home/ssd_storage/experiments/MR/vggtested/results/cf_vi/cf_vi_vggface_trained_2_5_ids.csv')]

# %% [markdown]
#     results of the threshold extraction:
#     results.group(2) = 38
#     results.group(4) = accuracy (38)
#     results.group(6) = threshold (38)
#
#     results.group(7) = 37
#     results.group(9) = accuracy (37)
#     results.group(11) = threshold (37)
#
#     results.group(12) = 39
#     results.group(14) = accuracy (39)
#     results.group(16) = threshold (39)

# %%
# for csv_file in csv_list:
df = pd.read_csv(csv_list[0])

# %%
# df

# %%
#data prep:

# change unnamed column to 'pairs'
df.rename(columns = {list(df)[0]: 'pairs'}, inplace = True)

# %%
#split the tuples to two columns
df_splited = df['pairs'].str.split(',', expand=True)

# %%
#adding   
df.insert(loc=0, column='img1', value=df_splited[0] )
df.insert(loc=1, column='img2', value=df_splited[1] )

# %%
# Dropping old Name columns 
df.drop(columns =["pairs"], inplace = True)

# %%
#add a colums to detect 'hv' or 'cf'
df.insert(df.shape[1], "cf", True)
df.insert(df.shape[1], "hv", True)

# %%
#detect what are the cf and hv rows
df['cf']=df['type'].apply(lambda x: 'TRUE' if (x=="diff_pairs" or x=="same_pairs" or x=="high_ps_pairs" or x=="low_ps_pairs") else 'FALSE')
df['hv']=df['type'].apply(lambda x: 'TRUE' if (x=="frontal-ref" or x=="frontal-quarter_left" or x=="frontal-half_left" ) else 'FALSE')

# %%
#detecthe hv according to the images
img_in_hv = ((df.type=='diff_pairs') & ((df.img1 == "('CM46_2.png'") |(df.img1 == "('CM50_2.png'") | (df.img1 == "('CM51_2.png'") | (df.img1 == "('CM60_2.png'") | (df.img1 == "('CM61_2.png'") | (df.img1 == "('CM62_2.png'") | (df.img1 == "('CM64_2.png'") | (df.img1 == "('CM80_2.png'") | (df.img1 == "('CM81_2.png'") | (df.img1 == "('CM82_2.png'") | (df.img1 == "('CM83_2.png'")))
df.loc[img_in_hv, 'hv']='TRUE'

# %%
# average accross index:
result_mean = df.groupby(['img1', 'img2','num_pics','num_ids','type','cf', 'hv']).mean().fc7.reset_index()
result_std = df.groupby(['img1', 'img2','num_pics','num_ids','type','cf']).std().fc7.reset_index()

# %%
result_mean
# Out:
#                img1                        img2  num_pics  num_ids  \
# 0     ('CM46_2.png'       'Cpict46_set1_0.png')         1        2
# 1     ('CM46_2.png'       'Cpict46_set1_0.png')         1        5
# 2     ('CM46_2.png'       'Cpict46_set1_0.png')         5        2
# 3     ('CM46_2.png'       'Cpict46_set1_0.png')         5        5
# 4     ('CM46_2.png'       'Cpict46_set1_0.png')        10        2
# ...             ...                         ...       ...      ...
# 2235  ('th_ref.png'   'l_05_hanks_nose_81.png')       100        5
# 2236  ('th_ref.png'   'l_05_hanks_nose_81.png')       200        2
# 2237  ('th_ref.png'   'l_05_hanks_nose_81.png')       200        5
# 2238  ('th_ref.png'   'l_05_hanks_nose_81.png')       300        2
# 2239  ('th_ref.png'   'l_05_hanks_nose_81.png')       300        5
#
#               type    cf     hv        fc7
# 0       same_pairs  TRUE  FALSE  84.332659
# 1       same_pairs  TRUE  FALSE   0.329204
# 2       same_pairs  TRUE  FALSE   0.139288
# 3       same_pairs  TRUE  FALSE   0.465628
# 4       same_pairs  TRUE  FALSE   0.318609
# ...            ...   ...    ...        ...
# 2235  low_ps_pairs  TRUE  FALSE   7.306317
# 2236  low_ps_pairs  TRUE  FALSE   2.035123
# 2237  low_ps_pairs  TRUE  FALSE   7.683650
# 2238  low_ps_pairs  TRUE  FALSE   3.538067
# 2239  low_ps_pairs  TRUE  FALSE   8.415557
#
# [2240 rows x 8 columns]

# %%
cf_max_value = result_mean.groupby(['num_ids', 'num_pics', 'cf']).max().fc7.reset_index()

# %%
cf_max_value = cf_max_value[cf_max_value.cf != 'FALSE']
#only cf rows
df_cf_to_norm = result_mean.copy()    
df_cf_to_norm = df_cf_to_norm[df_cf_to_norm.cf != 'FALSE']

# %%
#rename index colum:
df_cf_to_norm = df_cf_to_norm.reset_index()
df_cf_to_norm.rename(columns={"index": "orig_index"}, inplace=True)

#rename index colum:
cf_max_value = cf_max_value.reset_index()
cf_max_value.rename(columns={"index": "orig_index"}, inplace=True)

# %%
# cf_max_value

# %%
#divide by max:
for index, row in df_cf_to_norm.iterrows():
    print('index: ', index)
    value_to_divide = df_cf_to_norm.iloc[index]['fc7']
    num_ids=df_cf_to_norm.iloc[index]['num_ids']
    num_pics = df_cf_to_norm.iloc[index]['num_pics']
    cf=df_cf_to_norm.iloc[index]['cf']
#     type_ = df_cf_to_norm.iloc[index]['type']
    value_to_divide_by = cf_max_value.query("num_ids==@num_ids & num_pics==@num_pics & cf == @cf")["fc7"]
    normalized_value =  value_to_divide/ value_to_divide_by
    print('value_to_divide: ', value_to_divide)
    print('num_ids: ', num_ids)
    print('num_pics: ', num_pics)
    print('cf: ', cf)
#     print('type_: ', type_)
    print('value_to_divide_by: ', value_to_divide_by)
    print('normalized_value: ', normalized_value)

    df_cf_to_norm.at[index, 'fc7'] =  normalized_value
# Out:
# index:  0
# value_to_divide:  84.33265853984709
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.051604
# Name: fc7, dtype: float64
# index:  1
# value_to_divide:  0.32920373232433325
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.124231
# Name: fc7, dtype: float64
# index:  2
# value_to_divide:  0.13928813452000002
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.104897
# Name: fc7, dtype: float64
# index:  3
# value_to_divide:  0.46562816679999997
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.114331
# Name: fc7, dtype: float64
# index:  4
# value_to_divide:  0.31860867913999996
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.144945
# Name: fc7, dtype: float64
# index:  5
# value_to_divide:  0.8929867249999999
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.113416
# Name: fc7, dtype: float64
# index:  6
# value_to_divide:  0.5303371632366667
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.132019
# Name: fc7, dtype: float64
# index:  7
# value_to_divide:  0.9347767142000001
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.104353
# Name: fc7, dtype: float64
# index:  8
# value_to_divide:  0.41445521099999993
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.138628
# Name: fc7, dtype: float64
# index:  9
# value_to_divide:  1.2656478808333331
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.135139
# Name: fc7, dtype: float64
# index:  10
# value_to_divide:  0.6688432409866666
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.132451
# Name: fc7, dtype: float64
# index:  11
# value_to_divide:  2.2502675500000007
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.169015
# Name: fc7, dtype: float64
# index:  12
# value_to_divide:  0.5870105054733333
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.152799
# Name: fc7, dtype: float64
# index:  13
# value_to_divide:  2.7980468866666666
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.162718
# Name: fc7, dtype: float64
# index:  14
# value_to_divide:  1.0833512459999999
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.176785
# Name: fc7, dtype: float64
# index:  15
# value_to_divide:  3.2233658800000007
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.159267
# Name: fc7, dtype: float64
# index:  16
# value_to_divide:  53.478819188381664
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.032724
# Name: fc7, dtype: float64
# index:  17
# value_to_divide:  0.56953286415
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.214923
# Name: fc7, dtype: float64
# index:  18
# value_to_divide:  0.4246554096566667
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.319806
# Name: fc7, dtype: float64
# index:  19
# value_to_divide:  1.6723145833333342
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.410624
# Name: fc7, dtype: float64
# index:  20
# value_to_divide:  1.1378925039
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.517663
# Name: fc7, dtype: float64
# index:  21
# value_to_divide:  3.4991527330000003
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.444417
# Name: fc7, dtype: float64
# index:  22
# value_to_divide:  2.070507571146666
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.515419
# Name: fc7, dtype: float64
# index:  23
# value_to_divide:  4.0945623979
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.457094
# Name: fc7, dtype: float64
# index:  24
# value_to_divide:  1.1440771066533335
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.382672
# Name: fc7, dtype: float64
# index:  25
# value_to_divide:  5.51718382
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.589095
# Name: fc7, dtype: float64
# index:  26
# value_to_divide:  1.9838291481000003
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.392857
# Name: fc7, dtype: float64
# index:  27
# value_to_divide:  8.618162146666666
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.6473
# Name: fc7, dtype: float64
# index:  28
# value_to_divide:  2.2083644723533324
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.574837
# Name: fc7, dtype: float64
# index:  29
# value_to_divide:  11.434079743333333
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.66494
# Name: fc7, dtype: float64
# index:  30
# value_to_divide:  3.9164679646666656
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.639102
# Name: fc7, dtype: float64
# index:  31
# value_to_divide:  12.782934796666666
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.631606
# Name: fc7, dtype: float64
# index:  32
# value_to_divide:  187.19409617744728
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.114547
# Name: fc7, dtype: float64
# index:  33
# value_to_divide:  0.61543372593
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.232245
# Name: fc7, dtype: float64
# index:  34
# value_to_divide:  0.3410957922833333
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.256877
# Name: fc7, dtype: float64
# index:  35
# value_to_divide:  1.02657788642
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.252068
# Name: fc7, dtype: float64
# index:  36
# value_to_divide:  0.6111984111766664
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.278053
# Name: fc7, dtype: float64
# index:  37
# value_to_divide:  2.734386064666667
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.347286
# Name: fc7, dtype: float64
# index:  38
# value_to_divide:  1.1050574494333334
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.275086
# Name: fc7, dtype: float64
# index:  39
# value_to_divide:  3.3896777442333326
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.378404
# Name: fc7, dtype: float64
# index:  40
# value_to_divide:  0.9762845438333335
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.326549
# Name: fc7, dtype: float64
# index:  41
# value_to_divide:  3.5223008713333326
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.376092
# Name: fc7, dtype: float64
# index:  42
# value_to_divide:  2.748014764556667
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.544188
# Name: fc7, dtype: float64
# index:  43
# value_to_divide:  5.698231063333333
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.427988
# Name: fc7, dtype: float64
# index:  44
# value_to_divide:  2.0832854501666667
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.542279
# Name: fc7, dtype: float64
# index:  45
# value_to_divide:  6.417976196666667
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.373233
# Name: fc7, dtype: float64
# index:  46
# value_to_divide:  2.83667142
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.462898
# Name: fc7, dtype: float64
# index:  47
# value_to_divide:  6.936004933333333
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.342709
# Name: fc7, dtype: float64
# index:  48
# value_to_divide:  40.47253402145355
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.024766
# Name: fc7, dtype: float64
# index:  49
# value_to_divide:  0.23704636635200002
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.089454
# Name: fc7, dtype: float64
# index:  50
# value_to_divide:  0.18004249640666667
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.135589
# Name: fc7, dtype: float64
# index:  51
# value_to_divide:  0.6146992066499999
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.150935
# Name: fc7, dtype: float64
# index:  52
# value_to_divide:  0.5749927144633332
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.261582
# Name: fc7, dtype: float64
# index:  53
# value_to_divide:  1.3919149809999996
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.176783
# Name: fc7, dtype: float64
# index:  54
# value_to_divide:  0.7317577335000001
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.182159
# Name: fc7, dtype: float64
# index:  55
# value_to_divide:  1.5099512829
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.168562
# Name: fc7, dtype: float64
# index:  56
# value_to_divide:  0.6317567266766666
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.211311
# Name: fc7, dtype: float64
# index:  57
# value_to_divide:  2.2491248513333333
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.240149
# Name: fc7, dtype: float64
# index:  58
# value_to_divide:  1.1963549506999998
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.236914
# Name: fc7, dtype: float64
# index:  59
# value_to_divide:  3.8983131600000003
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.292798
# Name: fc7, dtype: float64
# index:  60
# value_to_divide:  1.2290716788866665
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.319927
# Name: fc7, dtype: float64
# index:  61
# value_to_divide:  5.777082710000001
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.335962
# Name: fc7, dtype: float64
# index:  62
# value_to_divide:  1.9865013823333333
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.324164
# Name: fc7, dtype: float64
# index:  63
# value_to_divide:  6.063123843333334
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.29958
# Name: fc7, dtype: float64
# index:  64
# value_to_divide:  30.79123682408874
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.018842
# Name: fc7, dtype: float64
# index:  65
# value_to_divide:  0.22065102501433334
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.083267
# Name: fc7, dtype: float64
# index:  66
# value_to_divide:  0.10103555696866669
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.076089
# Name: fc7, dtype: float64
# index:  67
# value_to_divide:  0.34931142688000005
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.085771
# Name: fc7, dtype: float64
# index:  68
# value_to_divide:  0.31982160285666666
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.145497
# Name: fc7, dtype: float64
# index:  69
# value_to_divide:  0.7277122547333335
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.092425
# Name: fc7, dtype: float64
# index:  70
# value_to_divide:  0.4397585912333334
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.109471
# Name: fc7, dtype: float64
# index:  71
# value_to_divide:  0.7219973320333332
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.0806
# Name: fc7, dtype: float64
# index:  72
# value_to_divide:  0.30635662483333326
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.102471
# Name: fc7, dtype: float64
# index:  73
# value_to_divide:  1.1236768042
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.11998
# Name: fc7, dtype: float64
# index:  74
# value_to_divide:  0.49525798269666677
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.098076
# Name: fc7, dtype: float64
# index:  75
# value_to_divide:  2.0075430119999997
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.150784
# Name: fc7, dtype: float64
# index:  76
# value_to_divide:  0.5014901599233333
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.130538
# Name: fc7, dtype: float64
# index:  77
# value_to_divide:  2.7398827399999997
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.159336
# Name: fc7, dtype: float64
# index:  78
# value_to_divide:  1.0652992253333333
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.173839
# Name: fc7, dtype: float64
# index:  79
# value_to_divide:  3.05947492
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.151169
# Name: fc7, dtype: float64
# index:  80
# value_to_divide:  54.64612477755916
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.033439
# Name: fc7, dtype: float64
# index:  81
# value_to_divide:  0.69808540812
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.263435
# Name: fc7, dtype: float64
# index:  82
# value_to_divide:  0.5628279428966668
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.423863
# Name: fc7, dtype: float64
# index:  83
# value_to_divide:  2.2637795941500003
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.555854
# Name: fc7, dtype: float64
# index:  84
# value_to_divide:  1.772912192006667
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.806553
# Name: fc7, dtype: float64
# index:  85
# value_to_divide:  4.772660213666668
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.606162
# Name: fc7, dtype: float64
# index:  86
# value_to_divide:  2.7758056265033337
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.690992
# Name: fc7, dtype: float64
# index:  87
# value_to_divide:  5.128594981766668
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.572527
# Name: fc7, dtype: float64
# index:  88
# value_to_divide:  1.4652055508133335
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.490084
# Name: fc7, dtype: float64
# index:  89
# value_to_divide:  6.58753982
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.703381
# Name: fc7, dtype: float64
# index:  90
# value_to_divide:  2.6342459188533334
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.521659
# Name: fc7, dtype: float64
# index:  91
# value_to_divide:  10.076480116666666
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.756833
# Name: fc7, dtype: float64
# index:  92
# value_to_divide:  3.0704743329099995
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.799244
# Name: fc7, dtype: float64
# index:  93
# value_to_divide:  14.35523045333333
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.834818
# Name: fc7, dtype: float64
# index:  94
# value_to_divide:  4.094608534
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.668172
# Name: fc7, dtype: float64
# index:  95
# value_to_divide:  14.788524576666669
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.730702
# Name: fc7, dtype: float64
# index:  96
# value_to_divide:  117.7678168728844
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.072064
# Name: fc7, dtype: float64
# index:  97
# value_to_divide:  0.6778939432386667
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.255815
# Name: fc7, dtype: float64
# index:  98
# value_to_divide:  0.38231120455666656
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.287916
# Name: fc7, dtype: float64
# index:  99
# value_to_divide:  1.1173764347333335
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.274363
# Name: fc7, dtype: float64
# index:  100
# value_to_divide:  0.8297748914166667
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.377491
# Name: fc7, dtype: float64
# index:  101
# value_to_divide:  2.6124038013333344
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.331794
# Name: fc7, dtype: float64
# index:  102
# value_to_divide:  1.2327328155966666
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.306869
# Name: fc7, dtype: float64
# index:  103
# value_to_divide:  3.3659969586666665
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.375761
# Name: fc7, dtype: float64
# index:  104
# value_to_divide:  1.1628700921333333
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.388958
# Name: fc7, dtype: float64
# index:  105
# value_to_divide:  3.548722905
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.378913
# Name: fc7, dtype: float64
# index:  106
# value_to_divide:  2.3797380487066664
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.471259
# Name: fc7, dtype: float64
# index:  107
# value_to_divide:  5.753828750000001
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.432164
# Name: fc7, dtype: float64
# index:  108
# value_to_divide:  1.8682611249099996
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.486308
# Name: fc7, dtype: float64
# index:  109
# value_to_divide:  5.7670356
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.335378
# Name: fc7, dtype: float64
# index:  110
# value_to_divide:  2.7675231766666664
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.451614
# Name: fc7, dtype: float64
# index:  111
# value_to_divide:  6.716609236666667
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.331868
# Name: fc7, dtype: float64
# index:  112
# value_to_divide:  62.57677398620833
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.038292
# Name: fc7, dtype: float64
# index:  113
# value_to_divide:  0.40343525665666663
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.152243
# Name: fc7, dtype: float64
# index:  114
# value_to_divide:  0.35160419357999995
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.264791
# Name: fc7, dtype: float64
# index:  115
# value_to_divide:  0.9862374418333332
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.242163
# Name: fc7, dtype: float64
# index:  116
# value_to_divide:  0.802175062983333
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.364935
# Name: fc7, dtype: float64
# index:  117
# value_to_divide:  2.0546316919999996
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.260953
# Name: fc7, dtype: float64
# index:  118
# value_to_divide:  1.14228440226
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.284353
# Name: fc7, dtype: float64
# index:  119
# value_to_divide:  2.5514999769666673
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.284835
# Name: fc7, dtype: float64
# index:  120
# value_to_divide:  1.0122238703466666
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.33857
# Name: fc7, dtype: float64
# index:  121
# value_to_divide:  3.4799580743333327
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.371571
# Name: fc7, dtype: float64
# index:  122
# value_to_divide:  1.6539576125166666
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.327533
# Name: fc7, dtype: float64
# index:  123
# value_to_divide:  5.865151270000001
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.440525
# Name: fc7, dtype: float64
# index:  124
# value_to_divide:  1.412868778266667
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.367769
# Name: fc7, dtype: float64
# index:  125
# value_to_divide:  6.610814016666666
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.384447
# Name: fc7, dtype: float64
# index:  126
# value_to_divide:  2.6393273799999997
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.430694
# Name: fc7, dtype: float64
# index:  127
# value_to_divide:  7.841558603333336
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.387452
# Name: fc7, dtype: float64
# index:  128
# value_to_divide:  197.16238855653796
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.120647
# Name: fc7, dtype: float64
# index:  129
# value_to_divide:  0.91978249885
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.347096
# Name: fc7, dtype: float64
# index:  130
# value_to_divide:  0.36257946395
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.273057
# Name: fc7, dtype: float64
# index:  131
# value_to_divide:  1.3284014505666668
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.326179
# Name: fc7, dtype: float64
# index:  132
# value_to_divide:  1.1802226863333334
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.53692
# Name: fc7, dtype: float64
# index:  133
# value_to_divide:  2.505954806333334
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.318274
# Name: fc7, dtype: float64
# index:  134
# value_to_divide:  1.5695076167666668
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.390703
# Name: fc7, dtype: float64
# index:  135
# value_to_divide:  2.3334641116666672
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.260495
# Name: fc7, dtype: float64
# index:  136
# value_to_divide:  1.0756132723
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.359773
# Name: fc7, dtype: float64
# index:  137
# value_to_divide:  3.7286099973333324
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.39812
# Name: fc7, dtype: float64
# index:  138
# value_to_divide:  1.6647793200000005
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.329676
# Name: fc7, dtype: float64
# index:  139
# value_to_divide:  6.800291803333333
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.510762
# Name: fc7, dtype: float64
# index:  140
# value_to_divide:  1.62620755314
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.423301
# Name: fc7, dtype: float64
# index:  141
# value_to_divide:  8.065819740000002
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.469062
# Name: fc7, dtype: float64
# index:  142
# value_to_divide:  3.085154663333333
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.503446
# Name: fc7, dtype: float64
# index:  143
# value_to_divide:  9.068670996666667
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.448084
# Name: fc7, dtype: float64
# index:  144
# value_to_divide:  184.37036409374141
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.112819
# Name: fc7, dtype: float64
# index:  145
# value_to_divide:  0.6686235452143331
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.252317
# Name: fc7, dtype: float64
# index:  146
# value_to_divide:  0.2352619868533333
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.177175
# Name: fc7, dtype: float64
# index:  147
# value_to_divide:  0.8989335595666664
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.220726
# Name: fc7, dtype: float64
# index:  148
# value_to_divide:  0.6556501481066666
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.298276
# Name: fc7, dtype: float64
# index:  149
# value_to_divide:  1.6040865259999997
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.20373
# Name: fc7, dtype: float64
# index:  150
# value_to_divide:  0.98872890692
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.246128
# Name: fc7, dtype: float64
# index:  151
# value_to_divide:  1.4014218009000001
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.156447
# Name: fc7, dtype: float64
# index:  152
# value_to_divide:  0.6612294400333332
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.221169
# Name: fc7, dtype: float64
# index:  153
# value_to_divide:  2.183721768
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.233166
# Name: fc7, dtype: float64
# index:  154
# value_to_divide:  0.8194906032066667
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.162283
# Name: fc7, dtype: float64
# index:  155
# value_to_divide:  3.4917649400000004
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.262263
# Name: fc7, dtype: float64
# index:  156
# value_to_divide:  0.8713542007333334
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.226813
# Name: fc7, dtype: float64
# index:  157
# value_to_divide:  4.66820949
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.271476
# Name: fc7, dtype: float64
# index:  158
# value_to_divide:  1.7752857796666668
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.289697
# Name: fc7, dtype: float64
# index:  159
# value_to_divide:  5.567579596666667
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.275095
# Name: fc7, dtype: float64
# index:  160
# value_to_divide:  180.31004163013085
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.110334
# Name: fc7, dtype: float64
# index:  161
# value_to_divide:  1.1449252401899999
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.432058
# Name: fc7, dtype: float64
# index:  162
# value_to_divide:  0.57435377362
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.432543
# Name: fc7, dtype: float64
# index:  163
# value_to_divide:  2.2898342871666673
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.562251
# Name: fc7, dtype: float64
# index:  164
# value_to_divide:  1.9566519715833333
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.890142
# Name: fc7, dtype: float64
# index:  165
# value_to_divide:  4.342350046333334
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.551509
# Name: fc7, dtype: float64
# index:  166
# value_to_divide:  2.6082017104666666
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.649269
# Name: fc7, dtype: float64
# index:  167
# value_to_divide:  4.1860825749
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.46731
# Name: fc7, dtype: float64
# index:  168
# value_to_divide:  1.4151704906333336
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.473348
# Name: fc7, dtype: float64
# index:  169
# value_to_divide:  5.289066991333333
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.564738
# Name: fc7, dtype: float64
# index:  170
# value_to_divide:  2.01059988828
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.398158
# Name: fc7, dtype: float64
# index:  171
# value_to_divide:  7.48784394
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.562404
# Name: fc7, dtype: float64
# index:  172
# value_to_divide:  2.4197705301199997
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.629866
# Name: fc7, dtype: float64
# index:  173
# value_to_divide:  10.669864170000002
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.620498
# Name: fc7, dtype: float64
# index:  174
# value_to_divide:  3.8281466960000006
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.62469
# Name: fc7, dtype: float64
# index:  175
# value_to_divide:  12.572119279999997
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.62119
# Name: fc7, dtype: float64
# index:  176
# value_to_divide:  83.55010720141583
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.051126
# Name: fc7, dtype: float64
# index:  177
# value_to_divide:  0.34166399345
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.128933
# Name: fc7, dtype: float64
# index:  178
# value_to_divide:  0.16104092712333326
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.121279
# Name: fc7, dtype: float64
# index:  179
# value_to_divide:  0.5462072447
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.134117
# Name: fc7, dtype: float64
# index:  180
# value_to_divide:  0.3468801758466667
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.157807
# Name: fc7, dtype: float64
# index:  181
# value_to_divide:  1.0089285840666666
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.128141
# Name: fc7, dtype: float64
# index:  182
# value_to_divide:  0.6373981105166668
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.15867
# Name: fc7, dtype: float64
# index:  183
# value_to_divide:  1.0786832208666666
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.120418
# Name: fc7, dtype: float64
# index:  184
# value_to_divide:  0.48367978728
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.161782
# Name: fc7, dtype: float64
# index:  185
# value_to_divide:  1.790820914666667
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.191214
# Name: fc7, dtype: float64
# index:  186
# value_to_divide:  0.7512219762666664
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.148764
# Name: fc7, dtype: float64
# index:  187
# value_to_divide:  3.0971351866666663
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.232622
# Name: fc7, dtype: float64
# index:  188
# value_to_divide:  0.8311908905766668
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.216359
# Name: fc7, dtype: float64
# index:  189
# value_to_divide:  3.884782133333334
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.225917
# Name: fc7, dtype: float64
# index:  190
# value_to_divide:  1.5489040286666664
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.252755
# Name: fc7, dtype: float64
# index:  191
# value_to_divide:  4.71311591
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.232875
# Name: fc7, dtype: float64
# index:  192
# value_to_divide:  97.04098175651876
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.059381
# Name: fc7, dtype: float64
# index:  193
# value_to_divide:  0.7293257279723335
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.275224
# Name: fc7, dtype: float64
# index:  194
# value_to_divide:  0.48430992366
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.364731
# Name: fc7, dtype: float64
# index:  195
# value_to_divide:  2.0338796187333332
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.499404
# Name: fc7, dtype: float64
# index:  196
# value_to_divide:  1.332392533446667
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.606147
# Name: fc7, dtype: float64
# index:  197
# value_to_divide:  4.389287925666667
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.557471
# Name: fc7, dtype: float64
# index:  198
# value_to_divide:  2.4644694984833326
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.61349
# Name: fc7, dtype: float64
# index:  199
# value_to_divide:  4.904390520033333
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.547498
# Name: fc7, dtype: float64
# index:  200
# value_to_divide:  1.3121766471
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.438899
# Name: fc7, dtype: float64
# index:  201
# value_to_divide:  6.029747682333332
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.643823
# Name: fc7, dtype: float64
# index:  202
# value_to_divide:  2.4577960422433334
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.486717
# Name: fc7, dtype: float64
# index:  203
# value_to_divide:  9.401986876666665
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.706173
# Name: fc7, dtype: float64
# index:  204
# value_to_divide:  2.576539756706666
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.670673
# Name: fc7, dtype: float64
# index:  205
# value_to_divide:  13.123556543333331
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.763191
# Name: fc7, dtype: float64
# index:  206
# value_to_divide:  3.7043292016666665
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.604485
# Name: fc7, dtype: float64
# index:  207
# value_to_divide:  14.598435916666663
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.72131
# Name: fc7, dtype: float64
# index:  208
# value_to_divide:  33.48635266619626
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.020491
# Name: fc7, dtype: float64
# index:  209
# value_to_divide:  0.5745865149166668
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.21683
# Name: fc7, dtype: float64
# index:  210
# value_to_divide:  0.5459513576599999
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.411153
# Name: fc7, dtype: float64
# index:  211
# value_to_divide:  1.0392173235666666
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.255172
# Name: fc7, dtype: float64
# index:  212
# value_to_divide:  0.9234189282966667
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.420092
# Name: fc7, dtype: float64
# index:  213
# value_to_divide:  3.1918127664666667
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.405383
# Name: fc7, dtype: float64
# index:  214
# value_to_divide:  1.3146455694266668
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.32726
# Name: fc7, dtype: float64
# index:  215
# value_to_divide:  4.350043115999999
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.485614
# Name: fc7, dtype: float64
# index:  216
# value_to_divide:  1.3882203280666667
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.464334
# Name: fc7, dtype: float64
# index:  217
# value_to_divide:  4.049343985999999
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.432367
# Name: fc7, dtype: float64
# index:  218
# value_to_divide:  3.1606979399333333
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.625912
# Name: fc7, dtype: float64
# index:  219
# value_to_divide:  7.02243142
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.527447
# Name: fc7, dtype: float64
# index:  220
# value_to_divide:  2.442947952106666
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.635899
# Name: fc7, dtype: float64
# index:  221
# value_to_divide:  8.443759153333332
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.491041
# Name: fc7, dtype: float64
# index:  222
# value_to_divide:  3.482438986666666
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.568276
# Name: fc7, dtype: float64
# index:  223
# value_to_divide:  7.797817216666667
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.385291
# Name: fc7, dtype: float64
# index:  224
# value_to_divide:  34.843217944305
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.021321
# Name: fc7, dtype: float64
# index:  225
# value_to_divide:  0.42125989095666666
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.15897
# Name: fc7, dtype: float64
# index:  226
# value_to_divide:  0.3114216140366667
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.23453
# Name: fc7, dtype: float64
# index:  227
# value_to_divide:  1.1513119719000002
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.282696
# Name: fc7, dtype: float64
# index:  228
# value_to_divide:  0.87018743689
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.395876
# Name: fc7, dtype: float64
# index:  229
# value_to_divide:  2.398524635666667
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.30463
# Name: fc7, dtype: float64
# index:  230
# value_to_divide:  1.3450776004299998
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.334835
# Name: fc7, dtype: float64
# index:  231
# value_to_divide:  2.8305619946666667
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.315988
# Name: fc7, dtype: float64
# index:  232
# value_to_divide:  0.9495330820999999
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.317601
# Name: fc7, dtype: float64
# index:  233
# value_to_divide:  3.934977083333334
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.420155
# Name: fc7, dtype: float64
# index:  234
# value_to_divide:  1.8157108831600004
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# ...
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.517085
# Name: fc7, dtype: float64
# index:  1507
# value_to_divide:  2.046206176666666
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.50243
# Name: fc7, dtype: float64
# index:  1508
# value_to_divide:  0.9631915564899998
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.438186
# Name: fc7, dtype: float64
# index:  1509
# value_to_divide:  3.6567925373333328
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.464439
# Name: fc7, dtype: float64
# index:  1510
# value_to_divide:  2.0827058193599997
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.518456
# Name: fc7, dtype: float64
# index:  1511
# value_to_divide:  5.290937851566666
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.59065
# Name: fc7, dtype: float64
# index:  1512
# value_to_divide:  1.9179353581333338
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.641514
# Name: fc7, dtype: float64
# index:  1513
# value_to_divide:  6.1251656766666684
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.654012
# Name: fc7, dtype: float64
# index:  1514
# value_to_divide:  3.029977774566667
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.600026
# Name: fc7, dtype: float64
# index:  1515
# value_to_divide:  8.459021873333334
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.635348
# Name: fc7, dtype: float64
# index:  1516
# value_to_divide:  2.6803004099466667
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.697682
# Name: fc7, dtype: float64
# index:  1517
# value_to_divide:  9.967246560000001
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.579638
# Name: fc7, dtype: float64
# index:  1518
# value_to_divide:  3.8845541153333345
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.633895
# Name: fc7, dtype: float64
# index:  1519
# value_to_divide:  10.270913646666667
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.507487
# Name: fc7, dtype: float64
# index:  1520
# value_to_divide:  910.2571688051677
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.556999
# Name: fc7, dtype: float64
# index:  1521
# value_to_divide:  2.1449981240266665
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.809453
# Name: fc7, dtype: float64
# index:  1522
# value_to_divide:  1.1394645680000002
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.858125
# Name: fc7, dtype: float64
# index:  1523
# value_to_divide:  3.637832238733334
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.893242
# Name: fc7, dtype: float64
# index:  1524
# value_to_divide:  2.070558806246666
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.941962
# Name: fc7, dtype: float64
# index:  1525
# value_to_divide:  6.066098728666668
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.770438
# Name: fc7, dtype: float64
# index:  1526
# value_to_divide:  3.5678749990666674
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.888165
# Name: fc7, dtype: float64
# index:  1527
# value_to_divide:  7.157364275999999
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.799007
# Name: fc7, dtype: float64
# index:  1528
# value_to_divide:  2.989703449333333
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    1.0
# Name: fc7, dtype: float64
# index:  1529
# value_to_divide:  7.802016026666665
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.833056
# Name: fc7, dtype: float64
# index:  1530
# value_to_divide:  3.8653036778866663
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.765445
# Name: fc7, dtype: float64
# index:  1531
# value_to_divide:  11.05239145
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.830133
# Name: fc7, dtype: float64
# index:  1532
# value_to_divide:  3.6194624149
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.942145
# Name: fc7, dtype: float64
# index:  1533
# value_to_divide:  11.766834200000003
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.684292
# Name: fc7, dtype: float64
# index:  1534
# value_to_divide:  5.105169633333333
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.833079
# Name: fc7, dtype: float64
# index:  1535
# value_to_divide:  12.58821895
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.621985
# Name: fc7, dtype: float64
# index:  1536
# value_to_divide:  866.3122494714199
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.530109
# Name: fc7, dtype: float64
# index:  1537
# value_to_divide:  1.7136025470633336
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.646658
# Name: fc7, dtype: float64
# index:  1538
# value_to_divide:  0.8306571979966666
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.625563
# Name: fc7, dtype: float64
# index:  1539
# value_to_divide:  3.24778878
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.79747
# Name: fc7, dtype: float64
# index:  1540
# value_to_divide:  1.1114462212733334
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.505632
# Name: fc7, dtype: float64
# index:  1541
# value_to_divide:  4.646255259666666
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.590107
# Name: fc7, dtype: float64
# index:  1542
# value_to_divide:  2.524295829406667
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.628382
# Name: fc7, dtype: float64
# index:  1543
# value_to_divide:  6.151342419333336
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.686701
# Name: fc7, dtype: float64
# index:  1544
# value_to_divide:  2.358198068
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.788773
# Name: fc7, dtype: float64
# index:  1545
# value_to_divide:  6.0883225266666665
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.650078
# Name: fc7, dtype: float64
# index:  1546
# value_to_divide:  3.59573885488
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.712063
# Name: fc7, dtype: float64
# index:  1547
# value_to_divide:  7.66917985
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.576023
# Name: fc7, dtype: float64
# index:  1548
# value_to_divide:  2.7296869389999996
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.710537
# Name: fc7, dtype: float64
# index:  1549
# value_to_divide:  9.274952843333335
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.539378
# Name: fc7, dtype: float64
# index:  1550
# value_to_divide:  4.117117016666667
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.671845
# Name: fc7, dtype: float64
# index:  1551
# value_to_divide:  9.32334588
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.460667
# Name: fc7, dtype: float64
# index:  1552
# value_to_divide:  500.68158546656815
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.306374
# Name: fc7, dtype: float64
# index:  1553
# value_to_divide:  1.1713197359866667
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.442018
# Name: fc7, dtype: float64
# index:  1554
# value_to_divide:  0.6935044365266665
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.522274
# Name: fc7, dtype: float64
# index:  1555
# value_to_divide:  2.232980827133333
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.548292
# Name: fc7, dtype: float64
# index:  1556
# value_to_divide:  0.8745458249799999
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.397858
# Name: fc7, dtype: float64
# index:  1557
# value_to_divide:  4.081999606666666
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.518443
# Name: fc7, dtype: float64
# index:  1558
# value_to_divide:  2.1706241216
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.540342
# Name: fc7, dtype: float64
# index:  1559
# value_to_divide:  5.647538574799999
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.630459
# Name: fc7, dtype: float64
# index:  1560
# value_to_divide:  2.1619934426
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.723146
# Name: fc7, dtype: float64
# index:  1561
# value_to_divide:  7.010021453333334
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.748492
# Name: fc7, dtype: float64
# index:  1562
# value_to_divide:  3.419840005143333
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.67723
# Name: fc7, dtype: float64
# index:  1563
# value_to_divide:  10.826548406666664
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.81317
# Name: fc7, dtype: float64
# index:  1564
# value_to_divide:  3.8417242628
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    1.0
# Name: fc7, dtype: float64
# index:  1565
# value_to_divide:  12.406512713333337
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.721492
# Name: fc7, dtype: float64
# index:  1566
# value_to_divide:  5.058958333333333
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.825538
# Name: fc7, dtype: float64
# index:  1567
# value_to_divide:  13.570932933333328
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.670541
# Name: fc7, dtype: float64
# index:  1568
# value_to_divide:  61.03785260264021
# num_ids:  2
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  0    1634.21548
# Name: fc7, dtype: float64
# normalized_value:  0    0.03735
# Name: fc7, dtype: float64
# index:  1569
# value_to_divide:  0.4422605235966667
# num_ids:  5
# num_pics:  1
# cf:  TRUE
# value_to_divide_by:  8    2.649936
# Name: fc7, dtype: float64
# normalized_value:  8    0.166895
# Name: fc7, dtype: float64
# index:  1570
# value_to_divide:  0.7439419875566667
# num_ids:  2
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  1    1.327855
# Name: fc7, dtype: float64
# normalized_value:  1    0.560259
# Name: fc7, dtype: float64
# index:  1571
# value_to_divide:  1.16126633135
# num_ids:  5
# num_pics:  5
# cf:  TRUE
# value_to_divide_by:  9    4.072616
# Name: fc7, dtype: float64
# normalized_value:  9    0.28514
# Name: fc7, dtype: float64
# index:  1572
# value_to_divide:  0.6523087786566666
# num_ids:  2
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  2    2.198134
# Name: fc7, dtype: float64
# normalized_value:  2    0.296756
# Name: fc7, dtype: float64
# index:  1573
# value_to_divide:  3.8045425579999996
# num_ids:  5
# num_pics:  10
# cf:  TRUE
# value_to_divide_by:  10    7.873574
# Name: fc7, dtype: float64
# normalized_value:  10    0.483204
# Name: fc7, dtype: float64
# index:  1574
# value_to_divide:  1.4730387173900001
# num_ids:  2
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  3    4.017133
# Name: fc7, dtype: float64
# normalized_value:  3    0.366689
# Name: fc7, dtype: float64
# index:  1575
# value_to_divide:  5.249322765866666
# num_ids:  5
# num_pics:  20
# cf:  TRUE
# value_to_divide_by:  11    8.95782
# Name: fc7, dtype: float64
# normalized_value:  11    0.586004
# Name: fc7, dtype: float64
# index:  1576
# value_to_divide:  1.6985053432333332
# num_ids:  2
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  4    2.989703
# Name: fc7, dtype: float64
# normalized_value:  4    0.568118
# Name: fc7, dtype: float64
# index:  1577
# value_to_divide:  5.175930067666667
# num_ids:  5
# num_pics:  50
# cf:  TRUE
# value_to_divide_by:  12    9.365532
# Name: fc7, dtype: float64
# normalized_value:  12    0.552657
# Name: fc7, dtype: float64
# index:  1578
# value_to_divide:  3.3456476894599994
# num_ids:  2
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  5    5.049748
# Name: fc7, dtype: float64
# normalized_value:  5    0.662538
# Name: fc7, dtype: float64
# index:  1579
# value_to_divide:  7.306317286666666
# num_ids:  5
# num_pics:  100
# cf:  TRUE
# value_to_divide_by:  13    13.314006
# Name: fc7, dtype: float64
# normalized_value:  13    0.548769
# Name: fc7, dtype: float64
# index:  1580
# value_to_divide:  2.03512266474
# num_ids:  2
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  6    3.841724
# Name: fc7, dtype: float64
# normalized_value:  6    0.529742
# Name: fc7, dtype: float64
# index:  1581
# value_to_divide:  7.6836497
# num_ids:  5
# num_pics:  200
# cf:  TRUE
# value_to_divide_by:  14    17.195644
# Name: fc7, dtype: float64
# normalized_value:  14    0.446837
# Name: fc7, dtype: float64
# index:  1582
# value_to_divide:  3.5380674133333327
# num_ids:  2
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  7    6.128076
# Name: fc7, dtype: float64
# normalized_value:  7    0.577354
# Name: fc7, dtype: float64
# index:  1583
# value_to_divide:  8.415556563333332
# num_ids:  5
# num_pics:  300
# cf:  TRUE
# value_to_divide_by:  15    20.238781
# Name: fc7, dtype: float64
# normalized_value:  15    0.415813
# Name: fc7, dtype: float64

# %%
# to test:
cf_max_value.loc[(cf_max_value['num_pics']==300) & (cf_max_value['num_ids']==5)]
result_mean.loc[(result_mean['num_pics']==5) & (result_mean['num_ids']==2)].fc7.max()
df_cf_to_norm.loc[df_cf_to_norm['fc7'] == 1]
# Out:
#       orig_index           img1                            img2  num_pics  \
# 331          331  ('CM55_2.png'    'Cpic55_set1_5_24_Lips.png')       100
# 333          333  ('CM55_2.png'    'Cpic55_set1_5_24_Lips.png')       200
# 334          334  ('CM55_2.png'    'Cpic55_set1_5_24_Lips.png')       300
# 335          335  ('CM55_2.png'    'Cpic55_set1_5_24_Lips.png')       300
# 979          979  ('ak_ref.png'    'h_05_kutcher_Brows_35.png')         5
# 980          980  ('ak_ref.png'    'h_05_kutcher_Brows_35.png')        10
# 981          981  ('ak_ref.png'    'h_05_kutcher_Brows_35.png')        10
# 982          982  ('ak_ref.png'    'h_05_kutcher_Brows_35.png')        20
# 983          983  ('ak_ref.png'    'h_05_kutcher_Brows_35.png')        20
# 985          985  ('ak_ref.png'    'h_05_kutcher_Brows_35.png')        50
# 1194        1850  ('gc_ref.png'      'l_05_clooney_24nose.png')       100
# 1312        1968  ('js_ref.png'                   'md_ref.png')         1
# 1313        1969  ('js_ref.png'                   'md_ref.png')         1
# 1426        2082  ('mz_ref.png'   'l_05_zukerberg_nose_69.png')         5
# 1528        2184  ('th_ref.png'                   'ak_ref.png')        50
# 1564        2220  ('th_ref.png'      'h_05_hanks_brows_39.png')       200
#
#       num_ids           type    cf     hv  fc7
# 331         5  high_ps_pairs  TRUE  FALSE  1.0
# 333         5  high_ps_pairs  TRUE  FALSE  1.0
# 334         2  high_ps_pairs  TRUE  FALSE  1.0
# 335         5  high_ps_pairs  TRUE  FALSE  1.0
# 979         5  high_ps_pairs  TRUE  FALSE  1.0
# 980         2  high_ps_pairs  TRUE  FALSE  1.0
# 981         5  high_ps_pairs  TRUE  FALSE  1.0
# 982         2  high_ps_pairs  TRUE  FALSE  1.0
# 983         5  high_ps_pairs  TRUE  FALSE  1.0
# 985         5  high_ps_pairs  TRUE  FALSE  1.0
# 1194        2   low_ps_pairs  TRUE  FALSE  1.0
# 1312        2     diff_pairs  TRUE  FALSE  1.0
# 1313        5     diff_pairs  TRUE  FALSE  1.0
# 1426        2   low_ps_pairs  TRUE  FALSE  1.0
# 1528        2     diff_pairs  TRUE  FALSE  1.0
# 1564        2  high_ps_pairs  TRUE  FALSE  1.0

# %%
# #make df of means (mean of every run)
# df_cf_means = df_cf_to_norm.groupby(['type','num_ids','num_pics']).mean()

# #make df of mean of means (mean of all run)
# df_cf_mean = df_cf_means.groupby(['type','num_ids','num_pics']).mean()

# #make df of SE of means (of all run)
# df_cf_se = df_cf_means.groupby(['type','num_ids','num_pics']).mean()
# print(df_cf_means )

# %%
#     #df of size of each type
#     size_df_views = df_views.groupby(['type']).count()
#     sqrt_size_views = np.sqrt(size_df_views)
#     se_views = std_views.transpose().div(sqrt_size_views).transpose()

# %% [markdown]
# ###############################hv##########################################

# %%
hv_max_value
# Out:
#     num_ids  num_pics    hv         fc7
# 1         2         1  TRUE  824.454820
# 3         2         5  TRUE    1.620384
# 5         2        10  TRUE    3.814906
# 7         2        20  TRUE    4.794591
# 9         2        50  TRUE    2.996581
# 11        2       100  TRUE    3.242510
# 13        2       200  TRUE    2.589194
# 15        2       300  TRUE    4.029217
# 17        5         1  TRUE    2.754010
# 19        5         5  TRUE    4.680327
# 21        5        10  TRUE    7.750242
# 23        5        20  TRUE    6.735599
# 25        5        50  TRUE    6.764370
# 27        5       100  TRUE    8.185285
# 29        5       200  TRUE   10.110710
# 31        5       300  TRUE   11.953422

# %%
hv_max_value = result_mean.groupby(['num_ids', 'num_pics', 'hv']).max().fc7.reset_index()

hv_max_value = hv_max_value[hv_max_value.hv != 'FALSE']
#only hv rows
df_hv_to_norm = result_mean.copy()    
df_hv_to_norm = df_hv_to_norm[df_hv_to_norm.cf == 'FALSE']

# %%
#only hv rows
df_hv_to_norm
# Out:
#                                   img1  \
# 1136  ('frontal/aligned/46_set1_0.jpg'
# 1137  ('frontal/aligned/46_set1_0.jpg'
# 1138  ('frontal/aligned/46_set1_0.jpg'
# 1139  ('frontal/aligned/46_set1_0.jpg'
# 1140  ('frontal/aligned/46_set1_0.jpg'
# ...                                ...
# 1787  ('frontal/aligned/85_set1_0.jpg'
# 1788  ('frontal/aligned/85_set1_0.jpg'
# 1789  ('frontal/aligned/85_set1_0.jpg'
# 1790  ('frontal/aligned/85_set1_0.jpg'
# 1791  ('frontal/aligned/85_set1_0.jpg'
#
#                                                    img2  num_pics  num_ids  \
# 1136   'half-left/cropped/bb/aligned/46_rs00657_9411...         1        2
# 1137   'half-left/cropped/bb/aligned/46_rs00657_9411...         1        5
# 1138   'half-left/cropped/bb/aligned/46_rs00657_9411...         5        2
# 1139   'half-left/cropped/bb/aligned/46_rs00657_9411...         5        5
# 1140   'half-left/cropped/bb/aligned/46_rs00657_9411...        10        2
# ...                                                 ...       ...      ...
# 1787                            'ref/aligned/85_2.jpg')       100        5
# 1788                            'ref/aligned/85_2.jpg')       200        2
# 1789                            'ref/aligned/85_2.jpg')       200        5
# 1790                            'ref/aligned/85_2.jpg')       300        2
# 1791                            'ref/aligned/85_2.jpg')       300        5
#
#                    type     cf    hv        fc7
# 1136  frontal-half_left  FALSE  TRUE  58.685512
# 1137  frontal-half_left  FALSE  TRUE   1.537870
# 1138  frontal-half_left  FALSE  TRUE   1.225722
# 1139  frontal-half_left  FALSE  TRUE   3.390343
# 1140  frontal-half_left  FALSE  TRUE   2.690929
# ...                 ...    ...   ...        ...
# 1787        frontal-ref  FALSE  TRUE   3.477882
# 1788        frontal-ref  FALSE  TRUE   1.100917
# 1789        frontal-ref  FALSE  TRUE   4.836153
# 1790        frontal-ref  FALSE  TRUE   1.848807
# 1791        frontal-ref  FALSE  TRUE   5.640807
#
# [656 rows x 8 columns]

# %%
#rename index colum:
df_hv_to_norm = df_hv_to_norm.reset_index()
df_hv_to_norm.rename(columns={"index": "orig_index"}, inplace=True)

#divide by max:
hv_max_value = hv_max_value.reset_index()

# %%
value_to_divide_by = hv_max_value.query("num_ids=='2' & num_pics=='1'")["fc7"]
value_to_divide_by
# Out:
# 0    824.45482
# Name: fc7, dtype: float64

# %%
for index, row in df_hv_to_norm.iterrows():
    print('index: ', index)
    value_to_divide = df_hv_to_norm.iloc[index]['fc7']
    num_ids=df_hv_to_norm.iloc[index]['num_ids']
    num_pics = df_hv_to_norm.iloc[index]['num_pics']
    hv=df_hv_to_norm.iloc[index]['hv']
#     type_ = df_cf_to_norm.iloc[index]['type']
    value_to_divide_by = hv_max_value.query("num_ids==@num_ids & num_pics==@num_pics & hv == @hv")["fc7"]
    normalized_value =  value_to_divide/ value_to_divide_by
    print('value_to_divide: ', value_to_divide)
    print('num_ids: ', num_ids)
    print('num_pics: ', num_pics)
    print('hv: ', hv)
#     print('type_: ', type_)
    print('value_to_divide_by: ', value_to_divide_by)
    print('normalized_value: ', normalized_value)

    df_hv_to_norm.at[index, 'fc7'] =  normalized_value


# df.to_csv(csv_file)
# Out:
# index:  0
# value_to_divide:  58.68551169081541
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.071181
# Name: fc7, dtype: float64
# index:  1
# value_to_divide:  1.5378697055866666
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.558411
# Name: fc7, dtype: float64
# index:  2
# value_to_divide:  1.2257223016833332
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.756439
# Name: fc7, dtype: float64
# index:  3
# value_to_divide:  3.390342983899999
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.724382
# Name: fc7, dtype: float64
# index:  4
# value_to_divide:  2.6909294033333326
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.705372
# Name: fc7, dtype: float64
# index:  5
# value_to_divide:  5.823927831
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.751451
# Name: fc7, dtype: float64
# index:  6
# value_to_divide:  3.6434446625
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.759907
# Name: fc7, dtype: float64
# index:  7
# value_to_divide:  5.300646797333334
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.78696
# Name: fc7, dtype: float64
# index:  8
# value_to_divide:  2.2180016708333334
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.740177
# Name: fc7, dtype: float64
# index:  9
# value_to_divide:  5.745927984999999
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.84944
# Name: fc7, dtype: float64
# index:  10
# value_to_divide:  2.373736056166666
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.732067
# Name: fc7, dtype: float64
# index:  11
# value_to_divide:  6.043686723333334
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.73836
# Name: fc7, dtype: float64
# index:  12
# value_to_divide:  1.8162246776999997
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.701463
# Name: fc7, dtype: float64
# index:  13
# value_to_divide:  6.422429076666668
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.63521
# Name: fc7, dtype: float64
# index:  14
# value_to_divide:  3.411187123333333
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.846613
# Name: fc7, dtype: float64
# index:  15
# value_to_divide:  7.7954857833333335
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.652155
# Name: fc7, dtype: float64
# index:  16
# value_to_divide:  132.025257989425
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.160136
# Name: fc7, dtype: float64
# index:  17
# value_to_divide:  1.1237293441333336
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.408034
# Name: fc7, dtype: float64
# index:  18
# value_to_divide:  0.8974675606400001
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.553861
# Name: fc7, dtype: float64
# index:  19
# value_to_divide:  2.393354251666666
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.511365
# Name: fc7, dtype: float64
# index:  20
# value_to_divide:  1.72943214719
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.453335
# Name: fc7, dtype: float64
# index:  21
# value_to_divide:  4.316631748333333
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.556967
# Name: fc7, dtype: float64
# index:  22
# value_to_divide:  2.6857816703999995
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.560169
# Name: fc7, dtype: float64
# index:  23
# value_to_divide:  4.207904774333332
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.624726
# Name: fc7, dtype: float64
# index:  24
# value_to_divide:  1.739028229733333
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.580337
# Name: fc7, dtype: float64
# index:  25
# value_to_divide:  5.1286248819999996
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.758182
# Name: fc7, dtype: float64
# index:  26
# value_to_divide:  1.9562695784199995
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.603319
# Name: fc7, dtype: float64
# index:  27
# value_to_divide:  5.420193820000001
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.662188
# Name: fc7, dtype: float64
# index:  28
# value_to_divide:  1.6325066579466665
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.630508
# Name: fc7, dtype: float64
# index:  29
# value_to_divide:  5.633322146666669
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.557164
# Name: fc7, dtype: float64
# index:  30
# value_to_divide:  2.9935120266666653
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.742951
# Name: fc7, dtype: float64
# index:  31
# value_to_divide:  6.564496126666667
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.549173
# Name: fc7, dtype: float64
# index:  32
# value_to_divide:  29.67625269601434
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.035995
# Name: fc7, dtype: float64
# index:  33
# value_to_divide:  0.170411321768
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.061878
# Name: fc7, dtype: float64
# index:  34
# value_to_divide:  0.09690753722333333
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.059805
# Name: fc7, dtype: float64
# index:  35
# value_to_divide:  0.31386454906666666
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.06706
# Name: fc7, dtype: float64
# index:  36
# value_to_divide:  0.26000876917666665
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.068156
# Name: fc7, dtype: float64
# index:  37
# value_to_divide:  0.6050164548333333
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.078064
# Name: fc7, dtype: float64
# index:  38
# value_to_divide:  0.37079616674666666
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.077336
# Name: fc7, dtype: float64
# index:  39
# value_to_divide:  0.7240918066000002
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.107502
# Name: fc7, dtype: float64
# index:  40
# value_to_divide:  0.30566726851000003
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.102005
# Name: fc7, dtype: float64
# index:  41
# value_to_divide:  0.9807053916666668
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.144981
# Name: fc7, dtype: float64
# index:  42
# value_to_divide:  0.4933457336733334
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.152149
# Name: fc7, dtype: float64
# index:  43
# value_to_divide:  1.5903596933333333
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.194295
# Name: fc7, dtype: float64
# index:  44
# value_to_divide:  0.4442668074866667
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.171585
# Name: fc7, dtype: float64
# index:  45
# value_to_divide:  2.1154119633333335
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.209225
# Name: fc7, dtype: float64
# index:  46
# value_to_divide:  0.9172811253333335
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.227657
# Name: fc7, dtype: float64
# index:  47
# value_to_divide:  2.7162362
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.227235
# Name: fc7, dtype: float64
# index:  48
# value_to_divide:  359.51024953524956
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.436058
# Name: fc7, dtype: float64
# index:  49
# value_to_divide:  1.4172459332566665
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.514612
# Name: fc7, dtype: float64
# index:  50
# value_to_divide:  1.0448334992433332
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.644806
# Name: fc7, dtype: float64
# index:  51
# value_to_divide:  2.6982430843666667
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.576507
# Name: fc7, dtype: float64
# index:  52
# value_to_divide:  1.9978623139333336
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.523699
# Name: fc7, dtype: float64
# index:  53
# value_to_divide:  4.870659645666668
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.628453
# Name: fc7, dtype: float64
# index:  54
# value_to_divide:  2.9563281926666667
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.616597
# Name: fc7, dtype: float64
# index:  55
# value_to_divide:  4.891613173666666
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.726233
# Name: fc7, dtype: float64
# index:  56
# value_to_divide:  2.201792994266667
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.734768
# Name: fc7, dtype: float64
# index:  57
# value_to_divide:  5.720871074333334
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.845736
# Name: fc7, dtype: float64
# index:  58
# value_to_divide:  2.354330086533333
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.726083
# Name: fc7, dtype: float64
# index:  59
# value_to_divide:  6.285901263333333
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.767951
# Name: fc7, dtype: float64
# index:  60
# value_to_divide:  1.9475352868499995
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.752178
# Name: fc7, dtype: float64
# index:  61
# value_to_divide:  7.0213577900000015
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.694448
# Name: fc7, dtype: float64
# index:  62
# value_to_divide:  3.3567374756666672
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.833099
# Name: fc7, dtype: float64
# index:  63
# value_to_divide:  8.356022726666664
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.699049
# Name: fc7, dtype: float64
# index:  64
# value_to_divide:  14.736522004919708
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.017874
# Name: fc7, dtype: float64
# index:  65
# value_to_divide:  0.17482665589
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.063481
# Name: fc7, dtype: float64
# index:  66
# value_to_divide:  0.10133075735166666
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.062535
# Name: fc7, dtype: float64
# index:  67
# value_to_divide:  0.3162713981866666
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.067575
# Name: fc7, dtype: float64
# index:  68
# value_to_divide:  0.27183465679333335
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.071256
# Name: fc7, dtype: float64
# index:  69
# value_to_divide:  0.6300207083333335
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.08129
# Name: fc7, dtype: float64
# index:  70
# value_to_divide:  0.38331659991333333
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.079948
# Name: fc7, dtype: float64
# index:  71
# value_to_divide:  0.6835823096
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.101488
# Name: fc7, dtype: float64
# index:  72
# value_to_divide:  0.3248372552333334
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.108403
# Name: fc7, dtype: float64
# index:  73
# value_to_divide:  1.1001730806666665
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.162642
# Name: fc7, dtype: float64
# index:  74
# value_to_divide:  0.48436970181666666
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.149381
# Name: fc7, dtype: float64
# index:  75
# value_to_divide:  1.793450646666667
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.219107
# Name: fc7, dtype: float64
# index:  76
# value_to_divide:  0.5008849371666666
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.193452
# Name: fc7, dtype: float64
# index:  77
# value_to_divide:  2.3875858999999995
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.236144
# Name: fc7, dtype: float64
# index:  78
# value_to_divide:  1.0178421370000001
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.252615
# Name: fc7, dtype: float64
# index:  79
# value_to_divide:  2.818418256666667
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.235783
# Name: fc7, dtype: float64
# index:  80
# value_to_divide:  648.1069325934587
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.786104
# Name: fc7, dtype: float64
# index:  81
# value_to_divide:  1.712567796586667
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.621845
# Name: fc7, dtype: float64
# index:  82
# value_to_divide:  1.0323518738133335
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.637103
# Name: fc7, dtype: float64
# index:  83
# value_to_divide:  2.772311509333333
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.592333
# Name: fc7, dtype: float64
# index:  84
# value_to_divide:  1.840243533566667
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.482382
# Name: fc7, dtype: float64
# index:  85
# value_to_divide:  4.7858920320000005
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.617515
# Name: fc7, dtype: float64
# index:  86
# value_to_divide:  2.9119515970333345
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.607341
# Name: fc7, dtype: float64
# index:  87
# value_to_divide:  4.848938850000001
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.719897
# Name: fc7, dtype: float64
# index:  88
# value_to_divide:  2.2698979587666672
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.757496
# Name: fc7, dtype: float64
# index:  89
# value_to_divide:  5.598428056666666
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.827635
# Name: fc7, dtype: float64
# index:  90
# value_to_divide:  2.2951752633666667
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.707839
# Name: fc7, dtype: float64
# index:  91
# value_to_divide:  5.92396619
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.723734
# Name: fc7, dtype: float64
# index:  92
# value_to_divide:  1.971914541266667
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.761594
# Name: fc7, dtype: float64
# index:  93
# value_to_divide:  5.933463599999999
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.586849
# Name: fc7, dtype: float64
# index:  94
# value_to_divide:  3.1866360766666664
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.790882
# Name: fc7, dtype: float64
# index:  95
# value_to_divide:  7.229432899999998
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.6048
# Name: fc7, dtype: float64
# index:  96
# value_to_divide:  176.7821196745717
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.214423
# Name: fc7, dtype: float64
# index:  97
# value_to_divide:  0.5688278929466668
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.206545
# Name: fc7, dtype: float64
# index:  98
# value_to_divide:  0.20422584628999998
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.126035
# Name: fc7, dtype: float64
# index:  99
# value_to_divide:  0.7774459702333334
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.166109
# Name: fc7, dtype: float64
# index:  100
# value_to_divide:  0.54830758754
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.143728
# Name: fc7, dtype: float64
# index:  101
# value_to_divide:  1.4299845238000004
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.184508
# Name: fc7, dtype: float64
# index:  102
# value_to_divide:  0.8513245412000002
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.177559
# Name: fc7, dtype: float64
# index:  103
# value_to_divide:  1.3084350317666669
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.194257
# Name: fc7, dtype: float64
# index:  104
# value_to_divide:  0.6262161287666665
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.208977
# Name: fc7, dtype: float64
# index:  105
# value_to_divide:  2.119627171
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.313352
# Name: fc7, dtype: float64
# index:  106
# value_to_divide:  0.7726153257333335
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.238277
# Name: fc7, dtype: float64
# index:  107
# value_to_divide:  3.1952750900000004
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.390368
# Name: fc7, dtype: float64
# index:  108
# value_to_divide:  0.9050380526166664
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.349544
# Name: fc7, dtype: float64
# index:  109
# value_to_divide:  4.22915974
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.418285
# Name: fc7, dtype: float64
# index:  110
# value_to_divide:  1.5862484463333333
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.393687
# Name: fc7, dtype: float64
# index:  111
# value_to_divide:  5.284218166666665
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.442067
# Name: fc7, dtype: float64
# index:  112
# value_to_divide:  824.454820419326
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    1.0
# Name: fc7, dtype: float64
# index:  113
# value_to_divide:  2.7540099272666665
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    1.0
# Name: fc7, dtype: float64
# index:  114
# value_to_divide:  1.4174493712800003
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.874761
# Name: fc7, dtype: float64
# index:  115
# value_to_divide:  4.439783415133333
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.948605
# Name: fc7, dtype: float64
# index:  116
# value_to_divide:  3.3780947840333324
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.885499
# Name: fc7, dtype: float64
# index:  117
# value_to_divide:  7.0293131293333335
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.90698
# Name: fc7, dtype: float64
# index:  118
# value_to_divide:  4.406812398466667
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.919122
# Name: fc7, dtype: float64
# index:  119
# value_to_divide:  6.4258804598
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.954018
# Name: fc7, dtype: float64
# index:  120
# value_to_divide:  2.9552661114666665
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.986213
# Name: fc7, dtype: float64
# index:  121
# value_to_divide:  6.689330486666667
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.988907
# Name: fc7, dtype: float64
# index:  122
# value_to_divide:  2.8243864754
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.871049
# Name: fc7, dtype: float64
# index:  123
# value_to_divide:  7.319245820000001
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.894196
# Name: fc7, dtype: float64
# index:  124
# value_to_divide:  2.5891942267
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    1.0
# Name: fc7, dtype: float64
# index:  125
# value_to_divide:  8.715736166666668
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.86203
# Name: fc7, dtype: float64
# index:  126
# value_to_divide:  4.029217136666667
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    1.0
# Name: fc7, dtype: float64
# index:  127
# value_to_divide:  11.95342226666667
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    1.0
# Name: fc7, dtype: float64
# index:  128
# value_to_divide:  787.2201689303938
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.954837
# Name: fc7, dtype: float64
# index:  129
# value_to_divide:  1.751367965343333
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.635934
# Name: fc7, dtype: float64
# index:  130
# value_to_divide:  0.6791476536866666
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.419128
# Name: fc7, dtype: float64
# index:  131
# value_to_divide:  2.442132662866666
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.521787
# Name: fc7, dtype: float64
# index:  132
# value_to_divide:  1.3359888959333333
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.350202
# Name: fc7, dtype: float64
# index:  133
# value_to_divide:  3.96218023
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.511233
# Name: fc7, dtype: float64
# index:  134
# value_to_divide:  2.3837493066666666
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.497175
# Name: fc7, dtype: float64
# index:  135
# value_to_divide:  3.8924932906666667
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.577899
# Name: fc7, dtype: float64
# index:  136
# value_to_divide:  1.9493359532333332
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.65052
# Name: fc7, dtype: float64
# index:  137
# value_to_divide:  4.655665379999999
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.688263
# Name: fc7, dtype: float64
# index:  138
# value_to_divide:  1.8779481796866666
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.579165
# Name: fc7, dtype: float64
# index:  139
# value_to_divide:  6.0704485366666665
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.741629
# Name: fc7, dtype: float64
# index:  140
# value_to_divide:  1.964221427866667
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.758623
# Name: fc7, dtype: float64
# index:  141
# value_to_divide:  7.025401760000002
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.694848
# Name: fc7, dtype: float64
# index:  142
# value_to_divide:  3.209956902333333
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.79667
# Name: fc7, dtype: float64
# index:  143
# value_to_divide:  8.843410626666664
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.739822
# Name: fc7, dtype: float64
# index:  144
# value_to_divide:  249.8800276437521
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.303085
# Name: fc7, dtype: float64
# index:  145
# value_to_divide:  0.7314722792566667
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.265603
# Name: fc7, dtype: float64
# index:  146
# value_to_divide:  0.21563385896666665
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.133076
# Name: fc7, dtype: float64
# index:  147
# value_to_divide:  0.9587579887666666
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.204848
# Name: fc7, dtype: float64
# index:  148
# value_to_divide:  0.5204926000166666
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.136437
# Name: fc7, dtype: float64
# index:  149
# value_to_divide:  1.58278231
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.204224
# Name: fc7, dtype: float64
# index:  150
# value_to_divide:  0.9657781933333336
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.201431
# Name: fc7, dtype: float64
# index:  151
# value_to_divide:  1.4996309859999999
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.222643
# Name: fc7, dtype: float64
# index:  152
# value_to_divide:  0.7324656896666666
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.244434
# Name: fc7, dtype: float64
# index:  153
# value_to_divide:  1.9995301859999999
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.295597
# Name: fc7, dtype: float64
# index:  154
# value_to_divide:  0.8680348939733332
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.267705
# Name: fc7, dtype: float64
# index:  155
# value_to_divide:  3.214736143333333
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.392746
# Name: fc7, dtype: float64
# index:  156
# value_to_divide:  0.9604114976833333
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.370931
# Name: fc7, dtype: float64
# index:  157
# value_to_divide:  4.376702626666666
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.432878
# Name: fc7, dtype: float64
# index:  158
# value_to_divide:  1.8882807759999993
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.468647
# Name: fc7, dtype: float64
# index:  159
# value_to_divide:  5.469883726666667
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.4576
# Name: fc7, dtype: float64
# index:  160
# value_to_divide:  362.6280783778138
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.43984
# Name: fc7, dtype: float64
# index:  161
# value_to_divide:  2.351090327056667
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.853697
# Name: fc7, dtype: float64
# index:  162
# value_to_divide:  1.50750366498
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.930337
# Name: fc7, dtype: float64
# index:  163
# value_to_divide:  4.519380344333333
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.965612
# Name: fc7, dtype: float64
# index:  164
# value_to_divide:  3.677371894300001
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.963948
# Name: fc7, dtype: float64
# index:  165
# value_to_divide:  7.1425198273333335
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.921587
# Name: fc7, dtype: float64
# index:  166
# value_to_divide:  4.532654202766666
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.945368
# Name: fc7, dtype: float64
# index:  167
# value_to_divide:  6.212217490333332
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.922296
# Name: fc7, dtype: float64
# index:  168
# value_to_divide:  2.7359948268666674
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.913039
# Name: fc7, dtype: float64
# index:  169
# value_to_divide:  6.415322213333332
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.948399
# Name: fc7, dtype: float64
# index:  170
# value_to_divide:  2.7834314191333336
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.858419
# Name: fc7, dtype: float64
# index:  171
# value_to_divide:  7.05728389
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.862192
# Name: fc7, dtype: float64
# index:  172
# value_to_divide:  2.1180536017833327
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.818036
# Name: fc7, dtype: float64
# index:  173
# value_to_divide:  7.5336627000000025
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.745117
# Name: fc7, dtype: float64
# index:  174
# value_to_divide:  3.8220696733333335
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.948589
# Name: fc7, dtype: float64
# index:  175
# value_to_divide:  8.256753966666668
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.690744
# Name: fc7, dtype: float64
# index:  176
# value_to_divide:  181.25969395499928
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.219854
# Name: fc7, dtype: float64
# index:  177
# value_to_divide:  0.6868583576966667
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.249403
# Name: fc7, dtype: float64
# index:  178
# value_to_divide:  0.5281375874700001
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.325934
# Name: fc7, dtype: float64
# index:  179
# value_to_divide:  1.3367900229999998
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.285619
# Name: fc7, dtype: float64
# index:  180
# value_to_divide:  0.9999658024899999
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.262121
# Name: fc7, dtype: float64
# index:  181
# value_to_divide:  2.6356939859999997
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.340079
# Name: fc7, dtype: float64
# index:  182
# value_to_divide:  1.6381335374833335
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.341663
# Name: fc7, dtype: float64
# index:  183
# value_to_divide:  2.757006193233333
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.409319
# Name: fc7, dtype: float64
# index:  184
# value_to_divide:  1.2288521027333337
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.410085
# Name: fc7, dtype: float64
# index:  185
# value_to_divide:  3.862149645000001
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.570955
# Name: fc7, dtype: float64
# index:  186
# value_to_divide:  1.42895134065
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.440693
# Name: fc7, dtype: float64
# index:  187
# value_to_divide:  4.357272316666665
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.53233
# Name: fc7, dtype: float64
# index:  188
# value_to_divide:  1.3935611275
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.538222
# Name: fc7, dtype: float64
# index:  189
# value_to_divide:  4.244404929999999
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.419793
# Name: fc7, dtype: float64
# index:  190
# value_to_divide:  2.4457961733333335
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.607015
# Name: fc7, dtype: float64
# index:  191
# value_to_divide:  4.741554866666665
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.396669
# Name: fc7, dtype: float64
# index:  192
# value_to_divide:  100.79800066729943
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.12226
# Name: fc7, dtype: float64
# index:  193
# value_to_divide:  0.3639510256600001
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.132153
# Name: fc7, dtype: float64
# index:  194
# value_to_divide:  0.15249443359233336
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.09411
# Name: fc7, dtype: float64
# index:  195
# value_to_divide:  0.5973636334333333
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.127633
# Name: fc7, dtype: float64
# index:  196
# value_to_divide:  0.3756992637666668
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.098482
# Name: fc7, dtype: float64
# index:  197
# value_to_divide:  1.0413410428333332
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.134362
# Name: fc7, dtype: float64
# index:  198
# value_to_divide:  0.6678696760533335
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.139296
# Name: fc7, dtype: float64
# index:  199
# value_to_divide:  1.3072365991333335
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.194079
# Name: fc7, dtype: float64
# index:  200
# value_to_divide:  0.5738620194666668
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.191506
# Name: fc7, dtype: float64
# index:  201
# value_to_divide:  1.7248884176666666
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.254996
# Name: fc7, dtype: float64
# index:  202
# value_to_divide:  0.8164347671833333
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.251791
# Name: fc7, dtype: float64
# index:  203
# value_to_divide:  2.5732685899999996
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.314377
# Name: fc7, dtype: float64
# index:  204
# value_to_divide:  0.7602562063199999
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.293627
# Name: fc7, dtype: float64
# index:  205
# value_to_divide:  3.5411233766666665
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.350235
# Name: fc7, dtype: float64
# index:  206
# value_to_divide:  1.4638326616666668
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.363304
# Name: fc7, dtype: float64
# index:  207
# value_to_divide:  3.6628115700000006
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.306424
# Name: fc7, dtype: float64
# index:  208
# value_to_divide:  366.5637462095267
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.444614
# Name: fc7, dtype: float64
# index:  209
# value_to_divide:  1.0741763588733333
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.390041
# Name: fc7, dtype: float64
# index:  210
# value_to_divide:  0.5918318034166667
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.365242
# Name: fc7, dtype: float64
# index:  211
# value_to_divide:  1.6277289538333335
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.347781
# Name: fc7, dtype: float64
# index:  212
# value_to_divide:  1.1496007101333334
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.301344
# Name: fc7, dtype: float64
# index:  213
# value_to_divide:  3.0031628176666656
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.387493
# Name: fc7, dtype: float64
# index:  214
# value_to_divide:  1.8508907417666665
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.386037
# Name: fc7, dtype: float64
# index:  215
# value_to_divide:  2.9788606838666665
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.442256
# Name: fc7, dtype: float64
# index:  216
# value_to_divide:  1.4910811261333332
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.497594
# Name: fc7, dtype: float64
# index:  217
# value_to_divide:  4.1063151693333335
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.607051
# Name: fc7, dtype: float64
# index:  218
# value_to_divide:  1.5870062582666664
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.489438
# Name: fc7, dtype: float64
# index:  219
# value_to_divide:  5.134091569999999
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.627234
# Name: fc7, dtype: float64
# index:  220
# value_to_divide:  1.6403922395666666
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.633553
# Name: fc7, dtype: float64
# index:  221
# value_to_divide:  5.651136376666667
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.558926
# Name: fc7, dtype: float64
# index:  222
# value_to_divide:  2.918267523333334
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.724277
# Name: fc7, dtype: float64
# index:  223
# value_to_divide:  6.9081504266666665
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.577922
# Name: fc7, dtype: float64
# index:  224
# value_to_divide:  454.29548165154574
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.551025
# Name: fc7, dtype: float64
# index:  225
# value_to_divide:  1.2425884200866666
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.451192
# Name: fc7, dtype: float64
# index:  226
# value_to_divide:  0.6559037975233334
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.404783
# Name: fc7, dtype: float64
# index:  227
# value_to_divide:  2.0057048019333332
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.428539
# Name: fc7, dtype: float64
# index:  228
# value_to_divide:  1.0158641865800002
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.266288
# Name: fc7, dtype: float64
# index:  229
# value_to_divide:  3.921987687333333
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.506047
# Name: fc7, dtype: float64
# index:  230
# value_to_divide:  1.790988707866667
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.373544
# Name: fc7, dtype: float64
# index:  231
# value_to_divide:  4.6986500842
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.697585
# Name: fc7, dtype: float64
# index:  232
# value_to_divide:  1.947970172
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.650064
# Name: fc7, dtype: float64
# index:  233
# value_to_divide:  5.057149163333334
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.747616
# Name: fc7, dtype: float64
# index:  234
# value_to_divide:  3.2425103643533335
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    1.0
# Name: fc7, dtype: float64
# ...
# Name: fc7, dtype: float64
# index:  578
# value_to_divide:  1.4503674880933333
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.895076
# Name: fc7, dtype: float64
# index:  579
# value_to_divide:  3.787444989666667
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.809227
# Name: fc7, dtype: float64
# index:  580
# value_to_divide:  3.4079555809
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.893326
# Name: fc7, dtype: float64
# index:  581
# value_to_divide:  6.433016303666666
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.830041
# Name: fc7, dtype: float64
# index:  582
# value_to_divide:  4.062968788433334
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.847407
# Name: fc7, dtype: float64
# index:  583
# value_to_divide:  5.0380014693333335
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.747966
# Name: fc7, dtype: float64
# index:  584
# value_to_divide:  2.3298569927666666
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.777505
# Name: fc7, dtype: float64
# index:  585
# value_to_divide:  5.3292106089999995
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.787835
# Name: fc7, dtype: float64
# index:  586
# value_to_divide:  2.2306932106333335
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.687953
# Name: fc7, dtype: float64
# index:  587
# value_to_divide:  5.677612146666665
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.693636
# Name: fc7, dtype: float64
# index:  588
# value_to_divide:  2.0423601403333334
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.788801
# Name: fc7, dtype: float64
# index:  589
# value_to_divide:  6.915554176666666
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.683983
# Name: fc7, dtype: float64
# index:  590
# value_to_divide:  3.164572986666667
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.785406
# Name: fc7, dtype: float64
# index:  591
# value_to_divide:  8.726393523333336
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.730033
# Name: fc7, dtype: float64
# index:  592
# value_to_divide:  400.5099195227851
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.485788
# Name: fc7, dtype: float64
# index:  593
# value_to_divide:  1.3876506151633334
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.503866
# Name: fc7, dtype: float64
# index:  594
# value_to_divide:  0.5683428432099997
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.350746
# Name: fc7, dtype: float64
# index:  595
# value_to_divide:  1.760556264166667
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.376161
# Name: fc7, dtype: float64
# index:  596
# value_to_divide:  1.1411018305166667
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.299117
# Name: fc7, dtype: float64
# index:  597
# value_to_divide:  3.0746883573333337
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.396722
# Name: fc7, dtype: float64
# index:  598
# value_to_divide:  1.7863626377333337
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.372579
# Name: fc7, dtype: float64
# index:  599
# value_to_divide:  2.4791649527999993
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.368069
# Name: fc7, dtype: float64
# index:  600
# value_to_divide:  1.2727676707666666
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.42474
# Name: fc7, dtype: float64
# index:  601
# value_to_divide:  3.1535519809999997
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.4662
# Name: fc7, dtype: float64
# index:  602
# value_to_divide:  1.3139366054666664
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.405222
# Name: fc7, dtype: float64
# index:  603
# value_to_divide:  4.229779376666666
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.516754
# Name: fc7, dtype: float64
# index:  604
# value_to_divide:  1.4403330200666669
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.556286
# Name: fc7, dtype: float64
# index:  605
# value_to_divide:  5.1323552633333325
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.507616
# Name: fc7, dtype: float64
# index:  606
# value_to_divide:  2.5509277800000003
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.633108
# Name: fc7, dtype: float64
# index:  607
# value_to_divide:  6.3690271733333335
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.53282
# Name: fc7, dtype: float64
# index:  608
# value_to_divide:  7.252457071446709
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.008797
# Name: fc7, dtype: float64
# index:  609
# value_to_divide:  0.2702290428133332
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.098122
# Name: fc7, dtype: float64
# index:  610
# value_to_divide:  0.3079236322899999
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.190031
# Name: fc7, dtype: float64
# index:  611
# value_to_divide:  0.9050333910666667
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.19337
# Name: fc7, dtype: float64
# index:  612
# value_to_divide:  0.6116605959666667
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.160334
# Name: fc7, dtype: float64
# index:  613
# value_to_divide:  1.6135376237333332
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.208192
# Name: fc7, dtype: float64
# index:  614
# value_to_divide:  0.7876355681266666
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.164276
# Name: fc7, dtype: float64
# index:  615
# value_to_divide:  2.1148618069666667
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.313983
# Name: fc7, dtype: float64
# index:  616
# value_to_divide:  0.8303743685566667
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.277107
# Name: fc7, dtype: float64
# index:  617
# value_to_divide:  2.753224095666667
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.407019
# Name: fc7, dtype: float64
# index:  618
# value_to_divide:  1.2822101658233331
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.395437
# Name: fc7, dtype: float64
# index:  619
# value_to_divide:  3.4951243933333336
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.427001
# Name: fc7, dtype: float64
# index:  620
# value_to_divide:  1.1741010367
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.453462
# Name: fc7, dtype: float64
# index:  621
# value_to_divide:  3.6453896833333332
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.360547
# Name: fc7, dtype: float64
# index:  622
# value_to_divide:  1.81979484
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.45165
# Name: fc7, dtype: float64
# index:  623
# value_to_divide:  4.10357685
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.343297
# Name: fc7, dtype: float64
# index:  624
# value_to_divide:  18.43760451030875
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.022363
# Name: fc7, dtype: float64
# index:  625
# value_to_divide:  0.7398907579566667
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.268659
# Name: fc7, dtype: float64
# index:  626
# value_to_divide:  0.8332519634299999
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.514231
# Name: fc7, dtype: float64
# index:  627
# value_to_divide:  2.074418709366666
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.443221
# Name: fc7, dtype: float64
# index:  628
# value_to_divide:  1.6854685525333337
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.441811
# Name: fc7, dtype: float64
# index:  629
# value_to_divide:  4.011587054999999
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.517608
# Name: fc7, dtype: float64
# index:  630
# value_to_divide:  2.4316096255999997
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.507157
# Name: fc7, dtype: float64
# index:  631
# value_to_divide:  3.7846631066666676
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.56189
# Name: fc7, dtype: float64
# index:  632
# value_to_divide:  1.5625570576499996
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.521447
# Name: fc7, dtype: float64
# index:  633
# value_to_divide:  4.7900365166666665
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.708128
# Name: fc7, dtype: float64
# index:  634
# value_to_divide:  1.7243620821666665
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.531798
# Name: fc7, dtype: float64
# index:  635
# value_to_divide:  5.213391376666667
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.636922
# Name: fc7, dtype: float64
# index:  636
# value_to_divide:  1.6022819220666664
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.618834
# Name: fc7, dtype: float64
# index:  637
# value_to_divide:  5.918005016666669
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.58532
# Name: fc7, dtype: float64
# index:  638
# value_to_divide:  2.8584775913333327
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.709437
# Name: fc7, dtype: float64
# index:  639
# value_to_divide:  7.132820886666668
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.596718
# Name: fc7, dtype: float64
# index:  640
# value_to_divide:  81.643220951833
# num_ids:  2
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  0    824.45482
# Name: fc7, dtype: float64
# normalized_value:  0    0.099027
# Name: fc7, dtype: float64
# index:  641
# value_to_divide:  0.3203189723333334
# num_ids:  5
# num_pics:  1
# hv:  TRUE
# value_to_divide_by:  8    2.75401
# Name: fc7, dtype: float64
# normalized_value:  8    0.11631
# Name: fc7, dtype: float64
# index:  642
# value_to_divide:  0.16329161194166666
# num_ids:  2
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  1    1.620384
# Name: fc7, dtype: float64
# normalized_value:  1    0.100773
# Name: fc7, dtype: float64
# index:  643
# value_to_divide:  0.5830767907
# num_ids:  5
# num_pics:  5
# hv:  TRUE
# value_to_divide_by:  9    4.680327
# Name: fc7, dtype: float64
# normalized_value:  9    0.12458
# Name: fc7, dtype: float64
# index:  644
# value_to_divide:  0.34504270885333327
# num_ids:  2
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  2    3.814906
# Name: fc7, dtype: float64
# normalized_value:  2    0.090446
# Name: fc7, dtype: float64
# index:  645
# value_to_divide:  1.3609584473333334
# num_ids:  5
# num_pics:  10
# hv:  TRUE
# value_to_divide_by:  10    7.750242
# Name: fc7, dtype: float64
# normalized_value:  10    0.175602
# Name: fc7, dtype: float64
# index:  646
# value_to_divide:  0.7111773750533332
# num_ids:  2
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  3    4.794591
# Name: fc7, dtype: float64
# normalized_value:  3    0.148329
# Name: fc7, dtype: float64
# index:  647
# value_to_divide:  1.4790072292666665
# num_ids:  5
# num_pics:  20
# hv:  TRUE
# value_to_divide_by:  11    6.735599
# Name: fc7, dtype: float64
# normalized_value:  11    0.219581
# Name: fc7, dtype: float64
# index:  648
# value_to_divide:  0.7578194075333332
# num_ids:  2
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  4    2.996581
# Name: fc7, dtype: float64
# normalized_value:  4    0.252895
# Name: fc7, dtype: float64
# index:  649
# value_to_divide:  2.409207565
# num_ids:  5
# num_pics:  50
# hv:  TRUE
# value_to_divide_by:  12    6.76437
# Name: fc7, dtype: float64
# normalized_value:  12    0.356161
# Name: fc7, dtype: float64
# index:  650
# value_to_divide:  1.113006873916667
# num_ids:  2
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  5    3.24251
# Name: fc7, dtype: float64
# normalized_value:  5    0.343255
# Name: fc7, dtype: float64
# index:  651
# value_to_divide:  3.4778824800000008
# num_ids:  5
# num_pics:  100
# hv:  TRUE
# value_to_divide_by:  13    8.185285
# Name: fc7, dtype: float64
# normalized_value:  13    0.424894
# Name: fc7, dtype: float64
# index:  652
# value_to_divide:  1.10091674476
# num_ids:  2
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  6    2.589194
# Name: fc7, dtype: float64
# normalized_value:  6    0.425197
# Name: fc7, dtype: float64
# index:  653
# value_to_divide:  4.836153
# num_ids:  5
# num_pics:  200
# hv:  TRUE
# value_to_divide_by:  14    10.11071
# Name: fc7, dtype: float64
# normalized_value:  14    0.47832
# Name: fc7, dtype: float64
# index:  654
# value_to_divide:  1.8488065256666666
# num_ids:  2
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  7    4.029217
# Name: fc7, dtype: float64
# normalized_value:  7    0.45885
# Name: fc7, dtype: float64
# index:  655
# value_to_divide:  5.640807003333335
# num_ids:  5
# num_pics:  300
# hv:  TRUE
# value_to_divide_by:  15    11.953422
# Name: fc7, dtype: float64
# normalized_value:  15    0.471899
# Name: fc7, dtype: float64

# %%
print(df_hv_mean)
print(df_cf_mean)
# Out:
#                                    level_0       fc7
# type        num_ids num_pics
# diff_pairs  2       1          2047.545455  0.188022
#                     5          6247.545455  0.220129
#                     10        10447.545455  0.197651
#                     20        14647.545455  0.269437
#                     50        18847.545455  0.268644
# ...                                    ...       ...
# frontal-ref 5       20        48336.000000  0.202749
#                     50        52536.000000  0.254712
#                     100       56736.000000  0.300618
#                     200       60936.000000  0.313744
#                     300       65136.000000  0.300376
#
# [64 rows x 2 columns]
#                              level_0       fc7
# type       num_ids num_pics
# diff_pairs 2       1          2042.0  0.398587
#                    5          6242.0  0.333172
#                    10        10442.0  0.323430
#                    20        14642.0  0.322780
#                    50        18842.0  0.313701
# ...                              ...       ...
# same_pairs 5       20        48316.0  0.233875
#                    50        52516.0  0.296732
#                    100       56716.0  0.331331
#                    200       60916.0  0.297801
#                    300       65116.0  0.280158
#
# [64 rows x 2 columns]

# %%
# pd.set_option('display.max_rows', None)

# %%
base_path = Path('/home/ssd_storage/experiments/MR/vggtested/results/cf_vi/after_norm_and_mean')
hv_file_name = 'hv_mean.csv'
cf_file_name = 'cf_mean.csv'
df_hv_mean.to_csv(os.path.join(base_path, hv_file_name))
df_cf_mean.to_csv(os.path.join(base_path, cf_file_name))
