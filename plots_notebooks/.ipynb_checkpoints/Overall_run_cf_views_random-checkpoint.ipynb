# %% [markdown]
# # an Overall code for CF and head views analysis for all csvs

# %% [markdown]
# imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from pathlib import Path
import openpyxl
import os
import re
import ggplot
from openpyxl import load_workbook
import xlsxwriter

# %% [markdown]
# parameters

# %% [markdown]
# experiments_folder: the folder with all the experiments we want to plot and make csvs for
#
# regex: the text we take from logs in each results to extract the threshold
#
# plot_kwards: the args for the results plot
#
# save..: if we want to save the plot/csv data of the results
#
# plot folder:dest path to save the plots
#
# mean_std_folder: dest path to csv data

# %%
for remote computer:
experiments_folder = Path('/home/administrator/experiments/all_ids/500_ids')
# experiments_folder = Path('/home/administrator/experiments/frontal_vs_variable')
regex =' (.*) threshold\\nlayer\s*\\n(\d*)(\s+)(\d*.\d*)(\s+)(\d*.\d*)\\n(\d*)(\s+)(\d*.\d*)(\s+)(\d*.\d*)\\n(\d*)(\s+)(\d*.\d*)(\s+)(\d*.\d*)'
plot_kwargs={'grid':True,'figsize':(20,8), 'fontsize':12}
save_views_plot = 0
save_cf_plot = 0
save_views_csv = 0
save_cf_csv = 0
save_mean_views_csv = 0
save_mean_cf_csv = 0
save_std_views_csv = 0
save_std_cf_csv = 0
save_se_views_csv = 0
save_se_cf_csv = 0
mean_std_folder=''
plots_folder = '/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/'
# plots_folder = '/home/administrator/plot_results/frontal_vs_variable/'
mean_folder_views='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/mean/views/'
std_folder_views='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/std/views/'
se_folder_views='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/se/views/'
mean_folder_cf='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/mean/cf/'
std_folder_cf='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/std/cf/'
se_folder_cf='/home/administrator/plot_results/all_ids/500_test/500_ids_num_changed/csv/se/cf/'

csv_list=[]
add_to_title = 'gaus_2'
excel_title = '500_ids'

# %%
# #for local computer:
# experiments_folder = Path(r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\50_10_ids_50_20_10_5_2_imgs')
# regex =' (.*) threshold\\nlayer\s*\\n(\d*)(\s+)(\d*.\d*)(\s+)(\d*.\d*)\\n(\d*)(\s+)(\d*.\d*)(\s+)(\d*.\d*)\\n(\d*)(\s+)(\d*.\d*)(\s+)(\d*.\d*)'
# plot_kwargs={'grid':True,'figsize':(20,8), 'fontsize':12}
# save_views_plot = 0
# save_cf_plot = 0
# save_views_csv = 0
# save_cf_csv = 0
# save_mean_views_csv = 0
# save_mean_cf_csv = 0
# save_std_views_csv = 0
# save_std_cf_csv = 0
# save_se_views_csv = 0
# save_se_cf_csv = 0
# mean_std_folder=''
# plots_folder = r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\results'
# mean_folder_views= r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\results\mean\views/'
# std_folder_views= r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\results\std\views/'
# se_folder_views= r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\results\se/views/'
# mean_folder_cf= r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\results/mean/cf/'
# std_folder_cf= r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\results/std/cf/'
# se_folder_cf= r'C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\results/se/cf/'

# csv_list=[]
# # add_to_title = 'gaus_2'
# # excel_title = '500_ids'

# %% [markdown]
# make the csvs list

# %%
for experiment in experiments_folder.iterdir():
    print(experiment)
    csv_list.append(Path(experiment))
print(csv_list)
# Out:
# C:\Users\mandy\OneDrive\Documents\studies\MA\lab\csv\raw\30_runs\50_10_ids_50_20_10_5_2_imgs\comparisons_with_fc7_linear.csv
# [WindowsPath('C:/Users/mandy/OneDrive/Documents/studies/MA/lab/csv/raw/30_runs/50_10_ids_50_20_10_5_2_imgs/comparisons_with_fc7_linear.csv')]

# %% [markdown]
#     results of the threshold extraction:
#     results.group(2) = 38
#     results.group(4) = accuracy (38)
#     results.group(6) = threshold (38)
#
#     results.group(7) = 37
#     results.group(9) = accuracy (37)
#     results.group(11) = threshold (37)
#
#     results.group(12) = 39
#     results.group(14) = accuracy (39)
#     results.group(16) = threshold (39)

# %%
for csv_file in csv_list:
    df = pd.read_csv(csv_file)
    
#     #data prep:
    
    # change unnamed column to 'pairs'
    df.rename(columns = {list(df)[0]: 'pairs'}, inplace = True)
    
    
    #split the tuples to two columns
    df_splited = df['pairs'].str.split(',', expand=True)

    #adding   
    df.insert(loc=0, column='img1', value=df_splited[0] )
    df.insert(loc=1, column='img2', value=df_splited[1] )


    # Dropping old Name columns 
    df.drop(columns =["pairs"], inplace = True) 
    
    #reorder columns by layer order
    df = df[['img1', 'img2', 'input', 'conv1', 'conv2', 'conv3', 'conv4', 'conv5', 'fc6', 'fc7', 'fc8','type', 'index','num_ids','num_pics']]

    #add a colums to detect 'hv' or 'cf'
    df.insert(12, "cf", True)
    df.insert(13, "hv", True)
    
    #detect what are the cf and hv rows
    df['cf']=df['type'].apply(lambda x: 'TRUE' if (x=="diff_pairs" or x=="same_pairs" or x=="high_ps_pairs" or x=="low_ps_pairs") else 'FALSE')
    df['hv']=df['type'].apply(lambda x: 'TRUE' if (x=="frontal-ref" or x=="frontal-quarter_left" or x=="frontal-half_left" ) else 'FALSE')

    
    #detecthe hv according to the images
    img_in_hv = ((df.type=='diff_pairs') & ((df.img1 == "('CM46_2.png'") |(df.img1 == "('CM50_2.png'") | (df.img1 == "('CM51_2.png'") | (df.img1 == "('CM60_2.png'") | (df.img1 == "('CM61_2.png'") | (df.img1 == "('CM62_2.png'") | (df.img1 == "('CM64_2.png'") | (df.img1 == "('CM80_2.png'") | (df.img1 == "('CM81_2.png'") | (df.img1 == "('CM82_2.png'") | (df.img1 == "('CM83_2.png'")))
    df.loc[img_in_hv, 'hv']='TRUE'
    
    #for each index run the normalization by max, mean and SE (in hv and cf separatly):
    ##############################cf###########################################
    cf_max_value = df.groupby(['index', 'cf']).max().fc7.reset_index()
    cf_max_value = cf_max_value[cf_max_value.cf != 'FALSE']
    #only cf rows
    df_cf_to_norm = df.copy()    
    df_cf_to_norm = df_cf_to_norm[df_cf_to_norm.cf != 'FALSE']
    
    #df with only fc7 layer
    df_cf_to_norm = df_cf_to_norm.drop(['input', 'conv1', 'conv2', 'conv3', 'conv4', 'conv5', 'fc6', 'fc8'], axis = 1)
        
    #divide by max:
    df_cf_to_norm = df_cf_to_norm.reset_index()

    for index, row in df_cf_to_norm.iterrows():
        run_index = df_cf_to_norm.iloc[index]['index'] # the running index of specific row
        #divide by max of the same run index in the max df
        value_to_be_devided = df_cf_to_norm.iloc[index]['fc7']
        value_to_divide_by = cf_max_value[cf_max_value['index']==run_index]['fc7']
        normalized_value =  value_to_be_devided/ value_to_divide_by
        df_cf_to_norm.at[index, 'fc7'] =  normalized_value
    
    #make df of means (mean of every run)
    df_cf_means = df_cf_to_norm.groupby(['type',  'index','num_ids','num_pics']).mean()
    
    #make df of mean of means (mean of all run)
    df_cf_mean = df_cf_means.groupby(['type','num_ids','num_pics']).mean()
    
    #make df of SE of means (of all run)
    df_cf_se = df_cf_means.groupby(['type','num_ids','num_pics']).mean()
    print(df_cf_se )
    
    #     #df of size of each type
#     size_df_views = df_views.groupby(['type']).count()
#     sqrt_size_views = np.sqrt(size_df_views)
#     se_views = std_views.transpose().div(sqrt_size_views).transpose()
    
    
    
    ###############################hv##########################################
    hv_max_value = df.groupby(['index', 'hv']).max().fc7.reset_index()
    hv_max_value = hv_max_value[hv_max_value.hv != 'FALSE']
    #only hv rows
    df_hv_to_norm = df[df.hv != 'FALSE'].copy()
    
    #df with only fc7 layer
    df_hv_to_norm = df_hv_to_norm.drop(['input', 'conv1', 'conv2', 'conv3', 'conv4', 'conv5', 'fc6', 'fc8'], axis = 1)

    #divide by max:
    df_hv_to_norm = df_hv_to_norm.reset_index()

    for index, row in df_hv_to_norm.iterrows():
        run_index = df_hv_to_norm.iloc[index]['index'] # the running index of specific row
        #divide by max of the same run index in the max df
        value_to_be_devided = df_hv_to_norm.iloc[index]['fc7']
        value_to_divide_by = hv_max_value[hv_max_value['index']==run_index]['fc7']
        normalized_value =  value_to_be_devided/ value_to_divide_by
        df_hv_to_norm.at[index, 'fc7'] =  normalized_value    
        
    #make df of means (mean of every run)
    df_hv_means = df_hv_to_norm.groupby(['type',  'index','num_ids','num_pics']).mean()
    
    #make df of mean of means (mean of all run)
    df_hv_mean = df_hv_means.groupby(['type','num_ids','num_pics']).mean()
    print(df_hv_mean )
    
    
    df.to_csv(csv_file)
# Out:
#                                 level_0       fc7
# type          num_ids num_pics
# diff_pairs    10      50         2056.5  0.507315
#               50      50         6286.5  0.527334
# high_ps_pairs 10      50         2081.5  0.594641
#               50      50         6311.5  0.684216
# low_ps_pairs  10      50         2106.5  0.500555
#               50      50         6336.5  0.365497
# same_pairs    10      50         2131.5  0.333975
#               50      50         6361.5  0.268321
#                                            level_0       fc7
# type                 num_ids num_pics
# diff_pairs           10      50        2062.045455  0.655070
#                      50      50        6292.045455  0.714492
# frontal-half_left    10      50        2179.500000  0.779385
#                      50      50        6409.500000  0.527934
# frontal-quarter_left 10      50        2166.500000  0.606282
#                      50      50        6396.500000  0.405766
# frontal-ref          10      50        2151.500000  0.291996
#                      50      50        6381.500000  0.252193

# %%
print(df_cf_to_norm)
# Out:
#       level_0           img1                                  img2       fc7  \
# 0           0  ('ak_ref.png'                         'ba_ref.png')  0.613337
# 1           1  ('ba_ref.png'                         'dd_ref.png')  0.369830
# 2           2  ('dd_ref.png'                         'gc_ref.png')  0.477929
# 3           3  ('gc_ref.png'                         'jb_ref.png')  0.576290
# 4           4  ('jb_ref.png'                         'js_ref.png')  0.443384
# 5           5  ('js_ref.png'                         'md_ref.png')  0.533483
# 6           6  ('md_ref.png'                         'mz_ref.png')  0.615130
# 7           7  ('mz_ref.png'                         'rn_ref.png')  0.436277
# 8           8  ('rn_ref.png'                         'th_ref.png')  0.509268
# 9           9  ('th_ref.png'                         'ak_ref.png')  0.903659
# 10         10  ('CM46_2.png'                 'Cpict47_set1_0.png')  0.218600
# 11         11  ('CM47_2.png'                 'Cpict48_set1_0.png')  0.288932
# 12         12  ('CM48_2.png'                  'Cpic50_set1_0.png')  0.310069
# 13         13  ('CM50_2.png'                  'Cpic51_set1_0.png')  0.336023
# 14         14  ('CM51_2.png'                  'Cpic55_set1_0.png')  0.353321
# 15         15  ('CM55_2.png'                 'Cpict60_set1_0.png')  0.411101
# 16         16  ('CM60_2.png'                 'Cpict61_set1_0.png')  0.350228
# 17         17  ('CM61_2.png'                 'Cpict62_set1_0.png')  0.418151
# 18         18  ('CM62_2.png'                 'Cpict64_set1_0.png')  0.287382
# 19         19  ('CM64_2.png'                 'Cpict80_set1_0.png')  0.433492
# 20         20  ('CM80_2.png'                 'Cpict81_set1_0.png')  0.220502
# 21         21  ('CM81_2.png'                  'Cpic82_set1_0.png')  0.313615
# 22         22  ('CM82_2.png'                 'Cpict83_set1_0.png')  0.431406
# 23         23  ('CM83_2.png'                  'Cpic85_set1_0.png')  0.311658
# 24         24  ('CM85_2.png'                 'Cpict46_set1_0.png')  0.517282
# 25         25  ('ak_ref.png'          'h_05_kutcher_Brows_35.png')  0.975878
# 26         26  ('ba_ref.png'    'h_05_affleck_76_brows_shape.png')  0.520253
# 27         27  ('dd_ref.png'     'h_05_duchovny_76_eye_brows.png')  0.321714
# 28         28  ('gc_ref.png'          'h_05_clooney_91_brows.png')  0.408267
# 29         29  ('jb_ref.png'           'h_05_bieber_35_brows.png')  0.373204
# 30         30  ('js_ref.png'         'h_05_seinfeld_Brows_32.png')  0.397039
# 31         31  ('md_ref.png'           'h_05_daimon_32_brows.png')  0.640963
# 32         32  ('mz_ref.png'        'h_05_zukerberg_Brows_64.png')  0.385779
# 33         33  ('rn_ref.png'           'h_05_deNiro_Brows_55.png')  0.563347
# 34         34  ('th_ref.png'            'h_05_hanks_brows_39.png')  1.000000
# 35         35  ('CM46_2.png'   'Cpict46_set1_5_24_lips_thick.png')  0.411440
# 36         36  ('CM47_2.png'     'Cpict47_set1_5_38_LipThick.png')  0.395131
# 37         37  ('CM48_2.png'         'Cpict48_set1_5_55_Lips.png')  0.492089
# 38         38  ('CM50_2.png'          'Cpic50_set1_5_69_Lips.png')  0.512077
# 39         39  ('CM51_2.png'           'Cpic51_set1_5_5_Lips.png')  0.446310
# 40         40  ('CM55_2.png'          'Cpic55_set1_5_24_Lips.png')  0.492154
# 41         41  ('CM60_2.png'         'Cpict60_set1_5_69_Lips.png')  0.299423
# 42         42  ('CM61_2.png'         'Cpict61_set1_5_91_Lips.png')  0.324852
# 43         43  ('CM62_2.png'          'Cpict62_set1_5_38Lips.png')  0.403137
# 44         44  ('CM64_2.png'         'Cpict64_set1_5_55_Lips.png')  0.194869
# 45         45  ('CM80_2.png'         'Cpict80_set1_5_91_Lips.png')  0.535973
# 46         46  ('CM81_2.png'          'Cpict81_set1_5_5_Lips.png')  0.292540
# 47         47  ('CM82_2.png'          'Cpic82_set1_5_69_Lips.png')  0.389214
# 48         48  ('CM83_2.png'         'Cpict83_set1_5_24_Lips.png')  0.403046
# 49         49  ('CM85_2.png'           'Cpic85_set1_5_5_Lips.png')  0.269896
# 50         50  ('ak_ref.png'           'l_05_kutcher_nose_66.png')  0.698725
# 51         51  ('ba_ref.png'           'l_05_affleck_95_nose.png')  0.608767
# 52         52  ('dd_ref.png'          'l_05_duchovny_48_nose.png')  0.548562
# 53         53  ('gc_ref.png'            'l_05_clooney_24nose.png')  0.771267
# 54         54  ('jb_ref.png'            'l_05_bieber_66_nose.png')  0.567229
# 55         55  ('js_ref.png'          'l_05_seinfeld_nose_57.png')  0.597173
# 56         56  ('md_ref.png'            'l_05_daimon_57_nose.png')  0.533560
# 57         57  ('mz_ref.png'         'l_05_zukerberg_nose_69.png')  0.454007
# 58         58  ('rn_ref.png'            'l_05_deNiro_nose_25.png')  0.432753
# 59         59  ('th_ref.png'             'l_05_hanks_nose_81.png')  0.451765
# 60         60  ('CM46_2.png'    'Cpict46_set3_5_43_MouthSize.png')  0.496045
# 61         61  ('CM47_2.png'         'Cpict47_set3_5_14_lips.png')  0.480355
# 62         62  ('CM48_2.png'         'Cpict48_set3_5_87_Lips.png')  0.640306
# 63         63  ('CM50_2.png'          'Cpic50_set3_5_22_Lips.png')  0.538788
# 64         64  ('CM51_2.png'         'Cpic51_set3_5_43_Mouth.png')  0.337474
# 65         65  ('CM55_2.png'         'Cpic55_set3_5_87_Mouth.png')  0.556454
# 66         66  ('CM60_2.png'        'Cpict60_set3_5_48_Mouth.png')  0.536989
# 67         67  ('CM61_2.png'       'Cpict61_set3_5_57_MouthB.png')  0.539499
# 68         68  ('CM62_2.png'    'Cpict62_set3_5_22_MouthSize.png')  0.530267
# 69         69  ('CM64_2.png'        'Cpict64_set3_5_14_Mouth.png')  0.400651
# 70         70  ('CM80_2.png'        'Cpict80_set3_5_43_Mouth.png')  0.602864
# 71         71  ('CM81_2.png'        'Cpict81_set3_5_87_Mouth.png')  0.327329
# 72         72  ('CM82_2.png'         'Cpic82_set3_5_14_Mouth.png')  0.330574
# 73         73  ('CM83_2.png'        'Cpict83_set3_5_57_Mouth.png')  0.797040
# 74         74  ('CM85_2.png'         'Cpic85_set3_5_57_Mouth.png')  0.572655
# 75         75  ('ak_ref.png'                   'h_00_kutcher.png')  0.635631
# 76         76  ('ba_ref.png'                   'h_00_affleck.png')  0.431848
# 77         77  ('dd_ref.png'                  'h_00_duchovny.png')  0.353765
# 78         78  ('gc_ref.png'                   'h_00_clooney.png')  0.478650
# 79         79  ('jb_ref.png'                    'h_00_bieber.png')  0.337513
# 80         80  ('js_ref.png'                  'h_00_seinfeld.png')  0.385407
# 81         81  ('md_ref.png'                    'h_00_daimon.png')  0.586939
# 82         82  ('mz_ref.png'                 'h_00_zukerberg.png')  0.316275
# 83         83  ('rn_ref.png'                    'h_00_deNiro.png')  0.130309
# 84         84  ('th_ref.png'                     'h_00_hanks.png')  0.761074
# 85         85  ('CM46_2.png'                 'Cpict46_set1_0.png')  0.119662
# 86         86  ('CM47_2.png'                 'Cpict47_set1_0.png')  0.092316
# 87         87  ('CM48_2.png'                 'Cpict48_set1_0.png')  0.149960
# 88         88  ('CM50_2.png'                  'Cpic50_set1_0.png')  0.135695
# 89         89  ('CM51_2.png'                  'Cpic51_set1_0.png')  0.226831
# 90         90  ('CM55_2.png'                  'Cpic55_set1_0.png')  0.436007
# 91         91  ('CM60_2.png'                 'Cpict60_set1_0.png')  0.106141
# 92         92  ('CM61_2.png'                 'Cpict61_set1_0.png')  0.104195
# 93         93  ('CM62_2.png'                 'Cpict62_set1_0.png')  0.102445
# 94         94  ('CM64_2.png'                 'Cpict64_set1_0.png')  0.141016
# 95         95  ('CM80_2.png'                 'Cpict80_set1_0.png')  0.134910
# 96         96  ('CM81_2.png'                 'Cpict81_set1_0.png')  0.123386
# 97         97  ('CM82_2.png'                  'Cpic82_set1_0.png')  0.097810
# 98         98  ('CM83_2.png'                 'Cpict83_set1_0.png')  0.260160
# 99         99  ('CM85_2.png'                  'Cpic85_set1_0.png')  0.398162
# 100       141  ('ak_ref.png'                         'ba_ref.png')  0.518053
# 101       142  ('ba_ref.png'                         'dd_ref.png')  0.494924
# 102       143  ('dd_ref.png'                         'gc_ref.png')  0.596852
# 103       144  ('gc_ref.png'                         'jb_ref.png')  0.532490
# 104       145  ('jb_ref.png'                         'js_ref.png')  0.529912
# 105       146  ('js_ref.png'                         'md_ref.png')  0.701109
# 106       147  ('md_ref.png'                         'mz_ref.png')  0.704570
# 107       148  ('mz_ref.png'                         'rn_ref.png')  0.533079
# 108       149  ('rn_ref.png'                         'th_ref.png')  0.766143
# 109       150  ('th_ref.png'                         'ak_ref.png')  0.754443
# 110       151  ('CM46_2.png'                 'Cpict47_set1_0.png')  0.243763
# 111       152  ('CM47_2.png'                 'Cpict48_set1_0.png')  0.423083
# 112       153  ('CM48_2.png'                  'Cpic50_set1_0.png')  0.479122
# 113       154  ('CM50_2.png'                  'Cpic51_set1_0.png')  0.434547
# 114       155  ('CM51_2.png'                  'Cpic55_set1_0.png')  0.387258
# 115       156  ('CM55_2.png'                 'Cpict60_set1_0.png')  0.713115
# 116       157  ('CM60_2.png'                 'Cpict61_set1_0.png')  0.381114
# 117       158  ('CM61_2.png'                 'Cpict62_set1_0.png')  0.618212
# 118       159  ('CM62_2.png'                 'Cpict64_set1_0.png')  0.421397
# 119       160  ('CM64_2.png'                 'Cpict80_set1_0.png')  0.403405
# 120       161  ('CM80_2.png'                 'Cpict81_set1_0.png')  0.353220
# 121       162  ('CM81_2.png'                  'Cpic82_set1_0.png')  0.371634
# 122       163  ('CM82_2.png'                 'Cpict83_set1_0.png')  0.368268
# 123       164  ('CM83_2.png'                  'Cpic85_set1_0.png')  0.427982
# 124       165  ('CM85_2.png'                 'Cpict46_set1_0.png')  0.340961
# 125       166  ('ak_ref.png'          'h_05_kutcher_Brows_35.png')  0.995324
# 126       167  ('ba_ref.png'    'h_05_affleck_76_brows_shape.png')  0.704742
# 127       168  ('dd_ref.png'     'h_05_duchovny_76_eye_brows.png')  0.594060
# 128       169  ('gc_ref.png'          'h_05_clooney_91_brows.png')  0.726884
# 129       170  ('jb_ref.png'           'h_05_bieber_35_brows.png')  0.647793
# 130       171  ('js_ref.png'         'h_05_seinfeld_Brows_32.png')  0.565252
# 131       172  ('md_ref.png'           'h_05_daimon_32_brows.png')  0.361215
# 132       173  ('mz_ref.png'        'h_05_zukerberg_Brows_64.png')  0.660582
# 133       174  ('rn_ref.png'           'h_05_deNiro_Brows_55.png')  1.000000
# 134       175  ('th_ref.png'            'h_05_hanks_brows_39.png')  0.916538
# 135       176  ('CM46_2.png'   'Cpict46_set1_5_24_lips_thick.png')  0.675820
# 136       177  ('CM47_2.png'     'Cpict47_set1_5_38_LipThick.png')  0.925234
# 137       178  ('CM48_2.png'         'Cpict48_set1_5_55_Lips.png')  0.724492
# 138       179  ('CM50_2.png'          'Cpic50_set1_5_69_Lips.png')  0.785745
# 139       180  ('CM51_2.png'           'Cpic51_set1_5_5_Lips.png')  0.427724
# 140       181  ('CM55_2.png'          'Cpic55_set1_5_24_Lips.png')  0.920537
# 141       182  ('CM60_2.png'         'Cpict60_set1_5_69_Lips.png')  0.372191
# 142       183  ('CM61_2.png'         'Cpict61_set1_5_91_Lips.png')  0.521892
# 143       184  ('CM62_2.png'          'Cpict62_set1_5_38Lips.png')  0.648756
# 144       185  ('CM64_2.png'         'Cpict64_set1_5_55_Lips.png')  0.610036
# 145       186  ('CM80_2.png'         'Cpict80_set1_5_91_Lips.png')  0.628465
# 146       187  ('CM81_2.png'          'Cpict81_set1_5_5_Lips.png')  0.335415
# 147       188  ('CM82_2.png'          'Cpic82_set1_5_69_Lips.png')  0.295587
# 148       189  ('CM83_2.png'         'Cpict83_set1_5_24_Lips.png')  0.708085
# 149       190  ('CM85_2.png'           'Cpic85_set1_5_5_Lips.png')  0.459183
# 150       191  ('ak_ref.png'           'l_05_kutcher_nose_66.png')  0.659280
# 151       192  ('ba_ref.png'           'l_05_affleck_95_nose.png')  0.459114
# 152       193  ('dd_ref.png'          'l_05_duchovny_48_nose.png')  0.632399
# 153       194  ('gc_ref.png'            'l_05_clooney_24nose.png')  0.618766
# 154       195  ('jb_ref.png'            'l_05_bieber_66_nose.png')  0.502127
# 155       196  ('js_ref.png'          'l_05_seinfeld_nose_57.png')  0.509245
# 156       197  ('md_ref.png'            'l_05_daimon_57_nose.png')  0.559793
# 157       198  ('mz_ref.png'         'l_05_zukerberg_nose_69.png')  0.493831
# 158       199  ('rn_ref.png'            'l_05_deNiro_nose_25.png')  0.535273
# 159       200  ('th_ref.png'             'l_05_hanks_nose_81.png')  0.514329
# 160       201  ('CM46_2.png'    'Cpict46_set3_5_43_MouthSize.png')  0.511628
# 161       202  ('CM47_2.png'         'Cpict47_set3_5_14_lips.png')  0.476422
# 162       203  ('CM48_2.png'         'Cpict48_set3_5_87_Lips.png')  0.700419
# 163       204  ('CM50_2.png'          'Cpic50_set3_5_22_Lips.png')  0.732585
# 164       205  ('CM51_2.png'         'Cpic51_set3_5_43_Mouth.png')  0.249728
# 165       206  ('CM55_2.png'         'Cpic55_set3_5_87_Mouth.png')  0.620141
# 166       207  ('CM60_2.png'        'Cpict60_set3_5_48_Mouth.png')  0.558883
# 167       208  ('CM61_2.png'       'Cpict61_set3_5_57_MouthB.png')  0.468129
# 168       209  ('CM62_2.png'    'Cpict62_set3_5_22_MouthSize.png')  0.697806
# 169       210  ('CM64_2.png'        'Cpict64_set3_5_14_Mouth.png')  0.387125
# 170       211  ('CM80_2.png'        'Cpict80_set3_5_43_Mouth.png')  0.675870
# 171       212  ('CM81_2.png'        'Cpict81_set3_5_87_Mouth.png')  0.317757
# 172       213  ('CM82_2.png'         'Cpic82_set3_5_14_Mouth.png')  0.285148
# 173       214  ('CM83_2.png'        'Cpict83_set3_5_57_Mouth.png')  0.925537
# 174       215  ('CM85_2.png'         'Cpic85_set3_5_57_Mouth.png')  0.828057
# 175       216  ('ak_ref.png'                   'h_00_kutcher.png')  0.679780
# 176       217  ('ba_ref.png'                   'h_00_affleck.png')  0.429116
# 177       218  ('dd_ref.png'                  'h_00_duchovny.png')  0.340382
# 178       219  ('gc_ref.png'                   'h_00_clooney.png')  0.511813
# 179       220  ('jb_ref.png'                    'h_00_bieber.png')  0.348113
# 180       221  ('js_ref.png'                  'h_00_seinfeld.png')  0.501503
# 181       222  ('md_ref.png'                    'h_00_daimon.png')  0.488779
# 182       223  ('mz_ref.png'                 'h_00_zukerberg.png')  0.752057
# 183       224  ('rn_ref.png'                    'h_00_deNiro.png')  0.257094
# 184       225  ('th_ref.png'                     'h_00_hanks.png')  0.636414
# 185       226  ('CM46_2.png'                 'Cpict46_set1_0.png')  0.132115
# 186       227  ('CM47_2.png'                 'Cpict47_set1_0.png')  0.130790
# 187       228  ('CM48_2.png'                 'Cpict48_set1_0.png')  0.277985
# 188       229  ('CM50_2.png'                  'Cpic50_set1_0.png')  0.229584
# 189       230  ('CM51_2.png'                  'Cpic51_set1_0.png')  0.240392
# 190       231  ('CM55_2.png'                  'Cpic55_set1_0.png')  0.516589
# 191       232  ('CM60_2.png'                 'Cpict60_set1_0.png')  0.163662
# 192       233  ('CM61_2.png'                 'Cpict61_set1_0.png')  0.144441
# 193       234  ('CM62_2.png'                 'Cpict62_set1_0.png')  0.170359
# 194       235  ('CM64_2.png'                 'Cpict64_set1_0.png')  0.265843
# 195       236  ('CM80_2.png'                 'Cpict80_set1_0.png')  0.182335
# 196       237  ('CM81_2.png'                 'Cpict81_set1_0.png')  0.191072
# 197       238  ('CM82_2.png'                  'Cpic82_set1_0.png')  0.151853
# 198       239  ('CM83_2.png'                 'Cpict83_set1_0.png')  0.275371
# 199       240  ('CM85_2.png'                  'Cpic85_set1_0.png')  0.499965
# 200       282  ('ak_ref.png'                         'ba_ref.png')  0.580722
# 201       283  ('ba_ref.png'                         'dd_ref.png')  0.457100
# 202       284  ('dd_ref.png'                         'gc_ref.png')  0.585430
# 203       285  ('gc_ref.png'                         'jb_ref.png')  0.530442
# 204       286  ('jb_ref.png'                         'js_ref.png')  0.620970
# 205       287  ('js_ref.png'                         'md_ref.png')  0.460490
# 206       288  ('md_ref.png'                         'mz_ref.png')  0.453928
# 207       289  ('mz_ref.png'                         'rn_ref.png')  0.476104
# 208       290  ('rn_ref.png'                         'th_ref.png')  0.553566
# 209       291  ('th_ref.png'                         'ak_ref.png')  0.680294
# 210       292  ('CM46_2.png'                 'Cpict47_set1_0.png')  0.273021
# 211       293  ('CM47_2.png'                 'Cpict48_set1_0.png')  0.392963
# 212       294  ('CM48_2.png'                  'Cpic50_set1_0.png')  0.422943
# 213       295  ('CM50_2.png'                  'Cpic51_set1_0.png')  0.430788
# 214       296  ('CM51_2.png'                  'Cpic55_set1_0.png')  0.416379
# 215       297  ('CM55_2.png'                 'Cpict60_set1_0.png')  0.631767
# 216       298  ('CM60_2.png'                 'Cpict61_set1_0.png')  0.461505
# 217       299  ('CM61_2.png'                 'Cpict62_set1_0.png')  0.605954
# 218       300  ('CM62_2.png'                 'Cpict64_set1_0.png')  0.630187
# 219       301  ('CM64_2.png'                 'Cpict80_set1_0.png')  0.478600
# 220       302  ('CM80_2.png'                 'Cpict81_set1_0.png')  0.435369
# 221       303  ('CM81_2.png'                  'Cpic82_set1_0.png')  0.444365
# 222       304  ('CM82_2.png'                 'Cpict83_set1_0.png')  0.423726
# 223       305  ('CM83_2.png'                  'Cpic85_set1_0.png')  0.380580
# 224       306  ('CM85_2.png'                 'Cpict46_set1_0.png')  0.483030
# 225       307  ('ak_ref.png'          'h_05_kutcher_Brows_35.png')  1.000000
# 226       308  ('ba_ref.png'    'h_05_affleck_76_brows_shape.png')  0.689513
# 227       309  ('dd_ref.png'     'h_05_duchovny_76_eye_brows.png')  0.558527
# 228       310  ('gc_ref.png'          'h_05_clooney_91_brows.png')  0.584213
# 229       311  ('jb_ref.png'           'h_05_bieber_35_brows.png')  0.636508
# 230       312  ('js_ref.png'         'h_05_seinfeld_Brows_32.png')  0.589072
# 231       313  ('md_ref.png'           'h_05_daimon_32_brows.png')  0.406410
# 232       314  ('mz_ref.png'        'h_05_zukerberg_Brows_64.png')  0.486882
# 233       315  ('rn_ref.png'           'h_05_deNiro_Brows_55.png')  0.799114
# 234       316  ('th_ref.png'            'h_05_hanks_brows_39.png')  0.519151
# 235       317  ('CM46_2.png'   'Cpict46_set1_5_24_lips_thick.png')  0.709134
# 236       318  ('CM47_2.png'     'Cpict47_set1_5_38_LipThick.png')  0.809399
# 237       319  ('CM48_2.png'         'Cpict48_set1_5_55_Lips.png')  0.523614
# 238       320  ('CM50_2.png'          'Cpic50_set1_5_69_Lips.png')  0.686285
# 239       321  ('CM51_2.png'           'Cpic51_set1_5_5_Lips.png')  0.367269
# 240       322  ('CM55_2.png'          'Cpic55_set1_5_24_Lips.png')  0.825104
# 241       323  ('CM60_2.png'         'Cpict60_set1_5_69_Lips.png')  0.421665
# 242       324  ('CM61_2.png'         'Cpict61_set1_5_91_Lips.png')  0.638036
# 243       325  ('CM62_2.png'          'Cpict62_set1_5_38Lips.png')  0.567939
# 244       326  ('CM64_2.png'         'Cpict64_set1_5_55_Lips.png')  0.738653
# 245       327  ('CM80_2.png'         'Cpict80_set1_5_91_Lips.png')  0.750469
# 246       328  ('CM81_2.png'          'Cpict81_set1_5_5_Lips.png')  0.389030
# 247       329  ('CM82_2.png'          'Cpic82_set1_5_69_Lips.png')  0.415191
# 248       330  ('CM83_2.png'         'Cpict83_set1_5_24_Lips.png')  0.667392
# 249       331  ('CM85_2.png'           'Cpic85_set1_5_5_Lips.png')  0.622681
# 250       332  ('ak_ref.png'           'l_05_kutcher_nose_66.png')  0.626832
# 251       333  ('ba_ref.png'           'l_05_affleck_95_nose.png')  0.463138
# 252       334  ('dd_ref.png'          'l_05_duchovny_48_nose.png')  0.442273
# 253       335  ('gc_ref.png'            'l_05_clooney_24nose.png')  0.476198
# 254       336  ('jb_ref.png'            'l_05_bieber_66_nose.png')  0.580335
# 255       337  ('js_ref.png'          'l_05_seinfeld_nose_57.png')  0.561613
# 256       338  ('md_ref.png'            'l_05_daimon_57_nose.png')  0.285179
# 257       339  ('mz_ref.png'         'l_05_zukerberg_nose_69.png')  0.610994
# 258       340  ('rn_ref.png'            'l_05_deNiro_nose_25.png')  0.387061
# 259       341  ('th_ref.png'             'l_05_hanks_nose_81.png')  0.345491
# 260       342  ('CM46_2.png'    'Cpict46_set3_5_43_MouthSize.png')  0.266446
# 261       343  ('CM47_2.png'         'Cpict47_set3_5_14_lips.png')  0.241812
# 262       344  ('CM48_2.png'         'Cpict48_set3_5_87_Lips.png')  0.372877
# 263       345  ('CM50_2.png'          'Cpic50_set3_5_22_Lips.png')  0.228233
# 264       346  ('CM51_2.png'         'Cpic51_set3_5_43_Mouth.png')  0.396595
# 265       347  ('CM55_2.png'         'Cpic55_set3_5_87_Mouth.png')  0.471830
# 266       348  ('CM60_2.png'        'Cpict60_set3_5_48_Mouth.png')  0.330831
# 267       349  ('CM61_2.png'       'Cpict61_set3_5_57_MouthB.png')  0.220667
# 268       350  ('CM62_2.png'    'Cpict62_set3_5_22_MouthSize.png')  0.275682
# 269       351  ('CM64_2.png'        'Cpict64_set3_5_14_Mouth.png')  0.286091
# 270       352  ('CM80_2.png'        'Cpict80_set3_5_43_Mouth.png')  0.246623
# 271       353  ('CM81_2.png'        'Cpict81_set3_5_87_Mouth.png')  0.467036
# 272       354  ('CM82_2.png'         'Cpic82_set3_5_14_Mouth.png')  0.216915
# 273       355  ('CM83_2.png'        'Cpict83_set3_5_57_Mouth.png')  0.443459
# 274       356  ('CM85_2.png'         'Cpic85_set3_5_57_Mouth.png')  0.561602
# 275       357  ('ak_ref.png'                   'h_00_kutcher.png')  0.511828
# 276       358  ('ba_ref.png'                   'h_00_affleck.png')  0.425450
# 277       359  ('dd_ref.png'                  'h_00_duchovny.png')  0.358163
# 278       360  ('gc_ref.png'                   'h_00_clooney.png')  0.388679
# 279       361  ('jb_ref.png'                    'h_00_bieber.png')  0.367559
# 280       362  ('js_ref.png'                  'h_00_seinfeld.png')  0.502628
# 281       363  ('md_ref.png'                    'h_00_daimon.png')  0.526013
# 282       364  ('mz_ref.png'                 'h_00_zukerberg.png')  0.476331
# 283       365  ('rn_ref.png'                    'h_00_deNiro.png')  0.300941
# 284       366  ('th_ref.png'                     'h_00_hanks.png')  0.523696
# 285       367  ('CM46_2.png'                 'Cpict46_set1_0.png')  0.146765
# 286       368  ('CM47_2.png'                 'Cpict47_set1_0.png')  0.147001
# 287       369  ('CM48_2.png'                 'Cpict48_set1_0.png')  0.311480
# 288       370  ('CM50_2.png'                  'Cpic50_set1_0.png')  0.211070
# 289       371  ('CM51_2.png'                  'Cpic51_set1_0.png')  0.267174
# 290       372  ('CM55_2.png'                  'Cpic55_set1_0.png')  0.398624
# 291       373  ('CM60_2.png'                 'Cpict60_set1_0.png')  0.197500
# 292       374  ('CM61_2.png'                 'Cpict61_set1_0.png')  0.185146
# 293       375  ('CM62_2.png'                 'Cpict62_set1_0.png')  0.168471
# 294       376  ('CM64_2.png'                 'Cpict64_set1_0.png')  0.349803
# 295       377  ('CM80_2.png'                 'Cpict80_set1_0.png')  0.229607
# 296       378  ('CM81_2.png'                 'Cpict81_set1_0.png')  0.233056
# 297       379  ('CM82_2.png'                  'Cpic82_set1_0.png')  0.227621
# 298       380  ('CM83_2.png'                 'Cpict83_set1_0.png')  0.327236
# 299       381  ('CM85_2.png'                  'Cpic85_set1_0.png')  0.507120
# 300       423  ('ak_ref.png'                         'ba_ref.png')  0.611072
# 301       424  ('ba_ref.png'                         'dd_ref.png')  0.555103
# 302       425  ('dd_ref.png'                         'gc_ref.png')  0.739031
# 303       426  ('gc_ref.png'                         'jb_ref.png')  0.365902
# 304       427  ('jb_ref.png'                         'js_ref.png')  0.455120
# 305       428  ('js_ref.png'                         'md_ref.png')  0.453309
# 306       429  ('md_ref.png'                         'mz_ref.png')  0.505141
# 307       430  ('mz_ref.png'                         'rn_ref.png')  0.427107
# 308       431  ('rn_ref.png'                         'th_ref.png')  0.615280
# 309       432  ('th_ref.png'                         'ak_ref.png')  0.969126
# 310       433  ('CM46_2.png'                 'Cpict47_set1_0.png')  0.199076
# 311       434  ('CM47_2.png'                 'Cpict48_set1_0.png')  0.328496
# 312       435  ('CM48_2.png'                  'Cpic50_set1_0.png')  0.443810
# 313       436  ('CM50_2.png'                  'Cpic51_set1_0.png')  0.263766
# 314       437  ('CM51_2.png'                  'Cpic55_set1_0.png')  0.312330
# 315       438  ('CM55_2.png'                 'Cpict60_set1_0.png')  0.503228
# 316       439  ('CM60_2.png'                 'Cpict61_set1_0.png')  0.330519
# 317       440  ('CM61_2.png'                 'Cpict62_set1_0.png')  0.338255
# 318       441  ('CM62_2.png'                 'Cpict64_set1_0.png')  0.349223
# 319       442  ('CM64_2.png'                 'Cpict80_set1_0.png')  0.377705
# 320       443  ('CM80_2.png'                 'Cpict81_set1_0.png')  0.262935
# 321       444  ('CM81_2.png'                  'Cpic82_set1_0.png')  0.336665
# 322       445  ('CM82_2.png'                 'Cpict83_set1_0.png')  0.395824
# 323       446  ('CM83_2.png'                  'Cpic85_set1_0.png')  0.412000
# 324       447  ('CM85_2.png'                 'Cpict46_set1_0.png')  0.307775
# 325       448  ('ak_ref.png'          'h_05_kutcher_Brows_35.png')  0.802046
# 326       449  ('ba_ref.png'    'h_05_affleck_76_brows_shape.png')  0.560274
# 327       450  ('dd_ref.png'     'h_05_duchovny_76_eye_brows.png')  0.624107
# 328       451  ('gc_ref.png'          'h_05_clooney_91_brows.png')  0.734774
# 329       452  ('jb_ref.png'           'h_05_bieber_35_brows.png')  0.503868
# 330       453  ('js_ref.png'         'h_05_seinfeld_Brows_32.png')  0.497522
# 331       454  ('md_ref.png'           'h_05_daimon_32_brows.png')  0.551206
# 332       455  ('mz_ref.png'        'h_05_zukerberg_Brows_64.png')  0.468334
# 333       456  ('rn_ref.png'           'h_05_deNiro_Brows_55.png')  0.712731
# 334       457  ('th_ref.png'            'h_05_hanks_brows_39.png')  1.000000
# 335       458  ('CM46_2.png'   'Cpict46_set1_5_24_lips_thick.png')  0.542658
# 336       459  ('CM47_2.png'     'Cpict47_set1_5_38_LipThick.png')  0.450606
# 337       460  ('CM48_2.png'         'Cpict48_set1_5_55_Lips.png')  0.451907
# 338       461  ('CM50_2.png'          'Cpic50_set1_5_69_Lips.png')  0.582050
# 339       462  ('CM51_2.png'           'Cpic51_set1_5_5_Lips.png')  0.438080
# 340       463  ('CM55_2.png'          'Cpic55_set1_5_24_Lips.png')  0.540742
# 341       464  ('CM60_2.png'         'Cpict60_set1_5_69_Lips.png')  0.236318
# 342       465  ('CM61_2.png'         'Cpict61_set1_5_91_Lips.png')  0.276651
# 343       466  ('CM62_2.png'          'Cpict62_set1_5_38Lips.png')  0.520128
# 344       467  ('CM64_2.png'         'Cpict64_set1_5_55_Lips.png')  0.267137
# 345       468  ('CM80_2.png'         'Cpict80_set1_5_91_Lips.png')  0.454257
# 346       469  ('CM81_2.png'          'Cpict81_set1_5_5_Lips.png')  0.373420
# 347       470  ('CM82_2.png'          'Cpic82_set1_5_69_Lips.png')  0.471496
# 348       471  ('CM83_2.png'         'Cpict83_set1_5_24_Lips.png')  0.316753
# 349       472  ('CM85_2.png'           'Cpic85_set1_5_5_Lips.png')  0.351464
# 350       473  ('ak_ref.png'           'l_05_kutcher_nose_66.png')  0.613750
# 351       474  ('ba_ref.png'           'l_05_affleck_95_nose.png')  0.536552
# 352       475  ('dd_ref.png'          'l_05_duchovny_48_nose.png')  0.629809
# 353       476  ('gc_ref.png'            'l_05_clooney_24nose.png')  0.725352
# 354       477  ('jb_ref.png'            'l_05_bieber_66_nose.png')  0.586863
# 355       478  ('js_ref.png'          'l_05_seinfeld_nose_57.png')  0.532277
# 356       479  ('md_ref.png'            'l_05_daimon_57_nose.png')  0.564152
# 357       480  ('mz_ref.png'         'l_05_zukerberg_nose_69.png')  0.448537
# 358       481  ('rn_ref.png'            'l_05_deNiro_nose_25.png')  0.385256
# 359       482  ('th_ref.png'             'l_05_hanks_nose_81.png')  0.553771
# 360       483  ('CM46_2.png'    'Cpict46_set3_5_43_MouthSize.png')  0.597825
# 361       484  ('CM47_2.png'         'Cpict47_set3_5_14_lips.png')  0.444150
# 362       485  ('CM48_2.png'         'Cpict48_set3_5_87_Lips.png')  0.569369
# 363       486  ('CM50_2.png'          'Cpic50_set3_5_22_Lips.png')  0.525436
# 364       487  ('CM51_2.png'         'Cpic51_set3_5_43_Mouth.png')  0.249923
# 365       488  ('CM55_2.png'         'Cpic55_set3_5_87_Mouth.png')  0.666186
# 366       489  ('CM60_2.png'        'Cpict60_set3_5_48_Mouth.png')  0.523514
# 367       490  ('CM61_2.png'       'Cpict61_set3_5_57_MouthB.png')  0.495576
# 368       491  ('CM62_2.png'    'Cpict62_set3_5_22_MouthSize.png')  0.590823
# 369       492  ('CM64_2.png'        'Cpict64_set3_5_14_Mouth.png')  0.442916
# 370       493  ('CM80_2.png'        'Cpict80_set3_5_43_Mouth.png')  0.592090
# 371       494  ('CM81_2.png'        'Cpict81_set3_5_87_Mouth.png')  0.225290
# 372       495  ('CM82_2.png'         'Cpic82_set3_5_14_Mouth.png')  0.239213
# 373       496  ('CM83_2.png'        'Cpict83_set3_5_57_Mouth.png')  0.718457
# 374       497  ('CM85_2.png'         'Cpic85_set3_5_57_Mouth.png')  0.547459
# 375       498  ('ak_ref.png'                   'h_00_kutcher.png')  0.591937
# 376       499  ('ba_ref.png'                   'h_00_affleck.png')  0.406283
# 377       500  ('dd_ref.png'                  'h_00_duchovny.png')  0.260164
# 378       501  ('gc_ref.png'                   'h_00_clooney.png')  0.450824
# 379       502  ('jb_ref.png'                    'h_00_bieber.png')  0.281867
# 380       503  ('js_ref.png'                  'h_00_seinfeld.png')  0.428758
# 381       504  ('md_ref.png'                    'h_00_daimon.png')  0.383422
# 382       505  ('mz_ref.png'                 'h_00_zukerberg.png')  0.436757
# 383       506  ('rn_ref.png'                    'h_00_deNiro.png')  0.252748
# 384       507  ('th_ref.png'                     'h_00_hanks.png')  0.576842
# 385       508  ('CM46_2.png'                 'Cpict46_set1_0.png')  0.120451
# 386       509  ('CM47_2.png'                 'Cpict47_set1_0.png')  0.089578
# 387       510  ('CM48_2.png'                 'Cpict48_set1_0.png')  0.179508
# 388       511  ('CM50_2.png'                  'Cpic50_set1_0.png')  0.166509
# 389       512  ('CM51_2.png'                  'Cpic51_set1_0.png')  0.219184
# 390       513  ('CM55_2.png'                  'Cpic55_set1_0.png')  0.443530
# 391       514  ('CM60_2.png'                 'Cpict60_set1_0.png')  0.130825
# 392       515  ('CM61_2.png'                 'Cpict61_set1_0.png')  0.109441
# 393       516  ('CM62_2.png'                 'Cpict62_set1_0.png')  0.140698
# 394       517  ('CM64_2.png'                 'Cpict64_set1_0.png')  0.198334
# 395       518  ('CM80_2.png'                 'Cpict80_set1_0.png')  0.158023
# 396       519  ('CM81_2.png'                 'Cpict81_set1_0.png')  0.150997
# 397       520  ('CM82_2.png'                  'Cpic82_set1_0.png')  0.128619
# 398       521  ('CM83_2.png'                 'Cpict83_set1_0.png')  0.241635
# 399       522  ('CM85_2.png'                  'Cpic85_set1_0.png')  0.389040
# 400       564  ('ak_ref.png'                         'ba_ref.png')  0.733118
# 401       565  ('ba_ref.png'                         'dd_ref.png')  0.419696
# 402       566  ('dd_ref.png'                         'gc_ref.png')  0.691473
# 403       567  ('gc_ref.png'                         'jb_ref.png')  0.655257
# 404       568  ('jb_ref.png'                         'js_ref.png')  0.507071
# 405       569  ('js_ref.png'                         'md_ref.png')  0.554985
# 406       570  ('md_ref.png'                         'mz_ref.png')  0.745301
# 407       571  ('mz_ref.png'                         'rn_ref.png')  0.587919
# 408       572  ('rn_ref.png'                         'th_ref.png')  0.491400
# 409       573  ('th_ref.png'                         'ak_ref.png')  0.936358
# 410       574  ('CM46_2.png'                 'Cpict47_set1_0.png')  0.338725
# 411       575  ('CM47_2.png'                 'Cpict48_set1_0.png')  0.325454
# 412       576  ('CM48_2.png'                  'Cpic50_set1_0.png')  0.547094
# 413       577  ('CM50_2.png'                  'Cpic51_set1_0.png')  0.506586
# 414       578  ('CM51_2.png'                  'Cpic55_set1_0.png')  0.408642
# 415       579  ('CM55_2.png'                 'Cpict60_set1_0.png')  0.584708
# 416       580  ('CM60_2.png'                 'Cpict61_set1_0.png')  0.458791
# 417       581  ('CM61_2.png'                 'Cpict62_set1_0.png')  0.637403
# 418       582  ('CM62_2.png'                 'Cpict64_set1_0.png')  0.395498
# 419       583  ('CM64_2.png'                 'Cpict80_set1_0.png')  0.500201
# 420       584  ('CM80_2.png'                 'Cpict81_set1_0.png')  0.383427
# 421       585  ('CM81_2.png'                  'Cpic82_set1_0.png')  0.459527
# 422       586  ('CM82_2.png'                 'Cpict83_set1_0.png')  0.436111
# 423       587  ('CM83_2.png'                  'Cpic85_set1_0.png')  0.492371
# 424       588  ('CM85_2.png'                 'Cpict46_set1_0.png')  0.568125
# 425       589  ('ak_ref.png'          'h_05_kutcher_Brows_35.png')  0.941943
# 426       590  ('ba_ref.png'    'h_05_affleck_76_brows_shape.png')  0.672875
# 427       591  ('dd_ref.png'     'h_05_duchovny_76_eye_brows.png')  0.501578
# 428       592  ('gc_ref.png'          'h_05_clooney_91_brows.png')  0.635353
# 429       593  ('jb_ref.png'           'h_05_bieber_35_brows.png')  0.549454
# 430       594  ('js_ref.png'         'h_05_seinfeld_Brows_32.png')  0.486489
# 431       595  ('md_ref.png'           'h_05_daimon_32_brows.png')  0.659655
# 432       596  ('mz_ref.png'        'h_05_zukerberg_Brows_64.png')  0.567108
# 433       597  ('rn_ref.png'           'h_05_deNiro_Brows_55.png')  0.839828
# 434       598  ('th_ref.png'            'h_05_hanks_brows_39.png')  1.000000
# 435       599  ('CM46_2.png'   'Cpict46_set1_5_24_lips_thick.png')  0.707312
# 436       600  ('CM47_2.png'     'Cpict47_set1_5_38_LipThick.png')  0.678511
# 437       601  ('CM48_2.png'         'Cpict48_set1_5_55_Lips.png')  0.468858
# 438       602  ('CM50_2.png'          'Cpic50_set1_5_69_Lips.png')  0.810038
# 439       603  ('CM51_2.png'           'Cpic51_set1_5_5_Lips.png')  0.517484
# 440       604  ('CM55_2.png'          'Cpic55_set1_5_24_Lips.png')  0.696877
# 441       605  ('CM60_2.png'         'Cpict60_set1_5_69_Lips.png')  0.341137
# 442       606  ('CM61_2.png'         'Cpict61_set1_5_91_Lips.png')  0.567757
# 443       607  ('CM62_2.png'          'Cpict62_set1_5_38Lips.png')  0.525371
# 444       608  ('CM64_2.png'         'Cpict64_set1_5_55_Lips.png')  0.382174
# 445       609  ('CM80_2.png'         'Cpict80_set1_5_91_Lips.png')  0.767735
# 446       610  ('CM81_2.png'          'Cpict81_set1_5_5_Lips.png')  0.482442
# 447       611  ('CM82_2.png'          'Cpic82_set1_5_69_Lips.png')  0.416342
# 448       612  ('CM83_2.png'         'Cpict83_set1_5_24_Lips.png')  0.577524
# 449       613  ('CM85_2.png'           'Cpic85_set1_5_5_Lips.png')  0.433073
# 450       614  ('ak_ref.png'           'l_05_kutcher_nose_66.png')  0.704281
# 451       615  ('ba_ref.png'           'l_05_affleck_95_nose.png')  0.520653
# 452       616  ('dd_ref.png'          'l_05_duchovny_48_nose.png')  0.595239
# 453       617  ('gc_ref.png'            'l_05_clooney_24nose.png')  0.560247
# 454       618  ('jb_ref.png'            'l_05_bieber_66_nose.png')  0.526412
# 455       619  ('js_ref.png'          'l_05_seinfeld_nose_57.png')  0.562645
# 456       620  ('md_ref.png'            'l_05_daimon_57_nose.png')  0.495939
# 457       621  ('mz_ref.png'         'l_05_zukerberg_nose_69.png')  0.569280
# 458       622  ('rn_ref.png'            'l_05_deNiro_nose_25.png')  0.428268
# 459       623  ('th_ref.png'             'l_05_hanks_nose_81.png')  0.423642
# 460       624  ('CM46_2.png'    'Cpict46_set3_5_43_MouthSize.png')  0.279597
# 461       625  ('CM47_2.png'         'Cpict47_set3_5_14_lips.png')  0.427172
# 462       626  ('CM48_2.png'         'Cpict48_set3_5_87_Lips.png')  0.468519
# 463       627  ('CM50_2.png'          'Cpic50_set3_5_22_Lips.png')  0.471817
# 464       628  ('CM51_2.png'         'Cpic51_set3_5_43_Mouth.png')  0.433219
# 465       629  ('CM55_2.png'         'Cpic55_set3_5_87_Mouth.png')  0.607677
# 466       630  ('CM60_2.png'        'Cpict60_set3_5_48_Mouth.png')  0.439122
# 467       631  ('CM61_2.png'       'Cpict61_set3_5_57_MouthB.png')  0.349329
# 468       632  ('CM62_2.png'    'Cpict62_set3_5_22_MouthSize.png')  0.290310
# 469       633  ('CM64_2.png'        'Cpict64_set3_5_14_Mouth.png')  0.296183
# 470       634  ('CM80_2.png'        'Cpict80_set3_5_43_Mouth.png')  0.376637
# 471       635  ('CM81_2.png'        'Cpict81_set3_5_87_Mouth.png')  0.362786
# 472       636  ('CM82_2.png'         'Cpic82_set3_5_14_Mouth.png')  0.229622
# 473       637  ('CM83_2.png'        'Cpict83_set3_5_57_Mouth.png')  0.490622
# 474       638  ('CM85_2.png'         'Cpic85_set3_5_57_Mouth.png')  0.660742
# 475       639  ('ak_ref.png'                   'h_00_kutcher.png')  0.603112
# 476       640  ('ba_ref.png'                   'h_00_affleck.png')  0.434689
# 477       641  ('dd_ref.png'                  'h_00_duchovny.png')  0.266556
# 478       642  ('gc_ref.png'                   'h_00_clooney.png')  0.463276
# 479       643  ('jb_ref.png'                    'h_00_bieber.png')  0.316801
# 480       644  ('js_ref.png'                  'h_00_seinfeld.png')  0.476278
# 481       645  ('md_ref.png'                    'h_00_daimon.png')  0.670020
# 482       646  ('mz_ref.png'                 'h_00_zukerberg.png')  0.434289
# 483       647  ('rn_ref.png'                    'h_00_deNiro.png')  0.211286
# 484       648  ('th_ref.png'                     'h_00_hanks.png')  0.528398
# 485       649  ('CM46_2.png'                 'Cpict46_set1_0.png')  0.149499
# 486       650  ('CM47_2.png'                 'Cpict47_set1_0.png')  0.130514
# 487       651  ('CM48_2.png'                 'Cpict48_set1_0.png')  0.226380
# 488       652  ('CM50_2.png'                  'Cpic50_set1_0.png')  0.213399
# 489       653  ('CM51_2.png'                  'Cpic51_set1_0.png')  0.316767
# 490       654  ('CM55_2.png'                  'Cpic55_set1_0.png')  0.518216
# 491       655  ('CM60_2.png'                 'Cpict60_set1_0.png')  0.148290
# 492       656  ('CM61_2.png'                 'Cpict61_set1_0.png')  0.204315
# 493       657  ('CM62_2.png'                 'Cpict62_set1_0.png')  0.170164
# 494       658  ('CM64_2.png'                 'Cpict64_set1_0.png')  0.260927
# 495       659  ('CM80_2.png'                 'Cpict80_set1_0.png')  0.222011
# 496       660  ('CM81_2.png'                 'Cpict81_set1_0.png')  0.225326
# 497       661  ('CM82_2.png'                  'Cpic82_set1_0.png')  0.170773
# 498       662  ('CM83_2.png'                 'Cpict83_set1_0.png')  0.392430
# 499       663  ('CM85_2.png'                  'Cpic85_set1_0.png')  0.551077
# 500       705  ('ak_ref.png'                         'ba_ref.png')  0.472718
# 501       706  ('ba_ref.png'                         'dd_ref.png')  0.444313
# 502       707  ('dd_ref.png'                         'gc_ref.png')  0.511562
# 503       708  ('gc_ref.png'                         'jb_ref.png')  0.495088
# 504       709  ('jb_ref.png'                         'js_ref.png')  0.477810
# 505       710  ('js_ref.png'                         'md_ref.png')  0.549155
# 506       711  ('md_ref.png'                         'mz_ref.png')  0.644384
# 507       712  ('mz_ref.png'                         'rn_ref.png')  0.580965
# 508       713  ('rn_ref.png'                         'th_ref.png')  0.519910
# 509       714  ('th_ref.png'                         'ak_ref.png')  0.713951
# 510       715  ('CM46_2.png'                 'Cpict47_set1_0.png')  0.223835
# 511       716  ('CM47_2.png'                 'Cpict48_set1_0.png')  0.372503
# 512       717  ('CM48_2.png'                  'Cpic50_set1_0.png')  0.489659
# 513       718  ('CM50_2.png'                  'Cpic51_set1_0.png')  0.348107
# 514       719  ('CM51_2.png'                  'Cpic55_set1_0.png')  0.287977
# 515       720  ('CM55_2.png'                 'Cpict60_set1_0.png')  0.769547
# 516       721  ('CM60_2.png'                 'Cpict61_set1_0.png')  0.400030
# 517       722  ('CM61_2.png'                 'Cpict62_set1_0.png')  0.464323
# 518       723  ('CM62_2.png'                 'Cpict64_set1_0.png')  0.415367
# 519       724  ('CM64_2.png'                 'Cpict80_set1_0.png')  0.356577
# 520       725  ('CM80_2.png'                 'Cpict81_set1_0.png')  0.357276
# 521       726  ('CM81_2.png'                  'Cpic82_set1_0.png')  0.343913
# 522       727  ('CM82_2.png'                 'Cpict83_set1_0.png')  0.435820
# 523       728  ('CM83_2.png'                  'Cpic85_set1_0.png')  0.446143
# 524       729  ('CM85_2.png'                 'Cpict46_set1_0.png')  0.481008
# 525       730  ('ak_ref.png'          'h_05_kutcher_Brows_35.png')  0.738942
# 526       731  ('ba_ref.png'    'h_05_affleck_76_brows_shape.png')  0.586272
# 527       732  ('dd_ref.png'     'h_05_duchovny_76_eye_brows.png')  0.635995
# 528       733  ('gc_ref.png'          'h_05_clooney_91_brows.png')  0.610569
# 529       734  ('jb_ref.png'           'h_05_bieber_35_brows.png')  0.574868
# 530       735  ('js_ref.png'         'h_05_seinfeld_Brows_32.png')  0.503371
# 531       736  ('md_ref.png'           'h_05_daimon_32_brows.png')  0.497519
# 532       737  ('mz_ref.png'        'h_05_zukerberg_Brows_64.png')  0.449185
# 533       738  ('rn_ref.png'           'h_05_deNiro_Brows_55.png')  0.770134
# 534       739  ('th_ref.png'            'h_05_hanks_brows_39.png')  0.675528
# 535       740  ('CM46_2.png'   'Cpict46_set1_5_24_lips_thick.png')  0.515603
# 536       741  ('CM47_2.png'     'Cpict47_set1_5_38_LipThick.png')  0.656521
# 537       742  ('CM48_2.png'         'Cpict48_set1_5_55_Lips.png')  0.409349
# 538       743  ('CM50_2.png'          'Cpic50_set1_5_69_Lips.png')  0.568596
# 539       744  ('CM51_2.png'           'Cpic51_set1_5_5_Lips.png')  0.290391
# 540       745  ('CM55_2.png'          'Cpic55_set1_5_24_Lips.png')  1.000000
# 541       746  ('CM60_2.png'         'Cpict60_set1_5_69_Lips.png')  0.291586
# 542       747  ('CM61_2.png'         'Cpict61_set1_5_91_Lips.png')  0.451016
# 543       748  ('CM62_2.png'          'Cpict62_set1_5_38Lips.png')  0.427344
# 544       749  ('CM64_2.png'         'Cpict64_set1_5_55_Lips.png')  0.508181
# 545       750  ('CM80_2.png'         'Cpict80_set1_5_91_Lips.png')  0.444316
# 546       751  ('CM81_2.png'          'Cpict81_set1_5_5_Lips.png')  0.341996
# 547       752  ('CM82_2.png'          'Cpic82_set1_5_69_Lips.png')  0.351887
# 548       753  ('CM83_2.png'         'Cpict83_set1_5_24_Lips.png')  0.613521
# 549       754  ('CM85_2.png'           'Cpic85_set1_5_5_Lips.png')  0.445013
# 550       755  ('ak_ref.png'           'l_05_kutcher_nose_66.png')  0.638827
# 551       756  ('ba_ref.png'           'l_05_affleck_95_nose.png')  0.487974
# 552       757  ('dd_ref.png'          'l_05_duchovny_48_nose.png')  0.604142
# 553       758  ('gc_ref.png'            'l_05_clooney_24nose.png')  0.759678
# 554       759  ('jb_ref.png'            'l_05_bieber_66_nose.png')  0.572496
# 555       760  ('js_ref.png'          'l_05_seinfeld_nose_57.png')  0.563733
# 556       761  ('md_ref.png'            'l_05_daimon_57_nose.png')  0.546817
# 557       762  ('mz_ref.png'         'l_05_zukerberg_nose_69.png')  0.627758
# 558       763  ('rn_ref.png'            'l_05_deNiro_nose_25.png')  0.579700
# 559       764  ('th_ref.png'             'l_05_hanks_nose_81.png')  0.643932
# 560       765  ('CM46_2.png'    'Cpict46_set3_5_43_MouthSize.png')  0.474173
# 561       766  ('CM47_2.png'         'Cpict47_set3_5_14_lips.png')  0.482616
# 562       767  ('CM48_2.png'         'Cpict48_set3_5_87_Lips.png')  0.701398
# 563       768  ('CM50_2.png'          'Cpic50_set3_5_22_Lips.png')  0.513193
# 564       769  ('CM51_2.png'         'Cpic51_set3_5_43_Mouth.png')  0.266249
# 565       770  ('CM55_2.png'         'Cpic55_set3_5_87_Mouth.png')  0.652803
# 566       771  ('CM60_2.png'        'Cpict60_set3_5_48_Mouth.png')  0.537492
# 567       772  ('CM61_2.png'       'Cpict61_set3_5_57_MouthB.png')  0.490971
# 568       773  ('CM62_2.png'    'Cpict62_set3_5_22_MouthSize.png')  0.485576
# 569       774  ('CM64_2.png'        'Cpict64_set3_5_14_Mouth.png')  0.464722
# 570       775  ('CM80_2.png'        'Cpict80_set3_5_43_Mouth.png')  0.588143
# 571       776  ('CM81_2.png'        'Cpict81_set3_5_87_Mouth.png')  0.272806
# 572       777  ('CM82_2.png'         'Cpic82_set3_5_14_Mouth.png')  0.193647
# 573       778  ('CM83_2.png'        'Cpict83_set3_5_57_Mouth.png')  0.693889
# 574       779  ('CM85_2.png'         'Cpic85_set3_5_57_Mouth.png')  0.718308
# 575       780  ('ak_ref.png'                   'h_00_kutcher.png')  0.663866
# 576       781  ('ba_ref.png'                   'h_00_affleck.png')  0.397223
# 577       782  ('dd_ref.png'                  'h_00_duchovny.png')  0.277866
# 578       783  ('gc_ref.png'                   'h_00_clooney.png')  0.567640
# 579       784  ('jb_ref.png'                    'h_00_bieber.png')  0.268623
# 580       785  ('js_ref.png'                  'h_00_seinfeld.png')  0.500254
# 581       786  ('md_ref.png'                    'h_00_daimon.png')  0.555133
# 582       787  ('mz_ref.png'                 'h_00_zukerberg.png')  0.462162
# 583       788  ('rn_ref.png'                    'h_00_deNiro.png')  0.286773
# 584       789  ('th_ref.png'                     'h_00_hanks.png')  0.586270
# 585       790  ('CM46_2.png'                 'Cpict46_set1_0.png')  0.151333
# 586       791  ('CM47_2.png'                 'Cpict47_set1_0.png')  0.117331
# 587       792  ('CM48_2.png'                 'Cpict48_set1_0.png')  0.238155
# 588       793  ('CM50_2.png'                  'Cpic50_set1_0.png')  0.240297
# 589       794  ('CM51_2.png'                  'Cpic51_set1_0.png')  0.249801
# 590       795  ('CM55_2.png'                  'Cpic55_set1_0.png')  0.676333
# 591       796  ('CM60_2.png'                 'Cpict60_set1_0.png')  0.161224
# 592       797  ('CM61_2.png'                 'Cpict61_set1_0.png')  0.149459
# 593       798  ('CM62_2.png'                 'Cpict62_set1_0.png')  0.138285
# 594       799  ('CM64_2.png'                 'Cpict64_set1_0.png')  0.232073
# 595       800  ('CM80_2.png'                 'Cpict80_set1_0.png')  0.178410
# 596       801  ('CM81_2.png'                 'Cpict81_set1_0.png')  0.220063
# 597       802  ('CM82_2.png'                  'Cpic82_set1_0.png')  0.168983
# 598       803  ('CM83_2.png'                 'Cpict83_set1_0.png')  0.224816
# ...
# 5738  high_ps_pairs  TRUE  FALSE     57       50        50
# 5739  high_ps_pairs  TRUE  FALSE     57       50        50
# 5740  high_ps_pairs  TRUE  FALSE     57       50        50
# 5741  high_ps_pairs  TRUE  FALSE     57       50        50
# 5742  high_ps_pairs  TRUE  FALSE     57       50        50
# 5743  high_ps_pairs  TRUE  FALSE     57       50        50
# 5744  high_ps_pairs  TRUE  FALSE     57       50        50
# 5745  high_ps_pairs  TRUE  FALSE     57       50        50
# 5746  high_ps_pairs  TRUE  FALSE     57       50        50
# 5747  high_ps_pairs  TRUE  FALSE     57       50        50
# 5748  high_ps_pairs  TRUE  FALSE     57       50        50
# 5749  high_ps_pairs  TRUE  FALSE     57       50        50
# 5750   low_ps_pairs  TRUE  FALSE     57       50        50
# 5751   low_ps_pairs  TRUE  FALSE     57       50        50
# 5752   low_ps_pairs  TRUE  FALSE     57       50        50
# 5753   low_ps_pairs  TRUE  FALSE     57       50        50
# 5754   low_ps_pairs  TRUE  FALSE     57       50        50
# 5755   low_ps_pairs  TRUE  FALSE     57       50        50
# 5756   low_ps_pairs  TRUE  FALSE     57       50        50
# 5757   low_ps_pairs  TRUE  FALSE     57       50        50
# 5758   low_ps_pairs  TRUE  FALSE     57       50        50
# 5759   low_ps_pairs  TRUE  FALSE     57       50        50
# 5760   low_ps_pairs  TRUE  FALSE     57       50        50
# 5761   low_ps_pairs  TRUE  FALSE     57       50        50
# 5762   low_ps_pairs  TRUE  FALSE     57       50        50
# 5763   low_ps_pairs  TRUE  FALSE     57       50        50
# 5764   low_ps_pairs  TRUE  FALSE     57       50        50
# 5765   low_ps_pairs  TRUE  FALSE     57       50        50
# 5766   low_ps_pairs  TRUE  FALSE     57       50        50
# 5767   low_ps_pairs  TRUE  FALSE     57       50        50
# 5768   low_ps_pairs  TRUE  FALSE     57       50        50
# 5769   low_ps_pairs  TRUE  FALSE     57       50        50
# 5770   low_ps_pairs  TRUE  FALSE     57       50        50
# 5771   low_ps_pairs  TRUE  FALSE     57       50        50
# 5772   low_ps_pairs  TRUE  FALSE     57       50        50
# 5773   low_ps_pairs  TRUE  FALSE     57       50        50
# 5774   low_ps_pairs  TRUE  FALSE     57       50        50
# 5775     same_pairs  TRUE  FALSE     57       50        50
# 5776     same_pairs  TRUE  FALSE     57       50        50
# 5777     same_pairs  TRUE  FALSE     57       50        50
# 5778     same_pairs  TRUE  FALSE     57       50        50
# 5779     same_pairs  TRUE  FALSE     57       50        50
# 5780     same_pairs  TRUE  FALSE     57       50        50
# 5781     same_pairs  TRUE  FALSE     57       50        50
# 5782     same_pairs  TRUE  FALSE     57       50        50
# 5783     same_pairs  TRUE  FALSE     57       50        50
# 5784     same_pairs  TRUE  FALSE     57       50        50
# 5785     same_pairs  TRUE  FALSE     57       50        50
# 5786     same_pairs  TRUE  FALSE     57       50        50
# 5787     same_pairs  TRUE  FALSE     57       50        50
# 5788     same_pairs  TRUE  FALSE     57       50        50
# 5789     same_pairs  TRUE  FALSE     57       50        50
# 5790     same_pairs  TRUE  FALSE     57       50        50
# 5791     same_pairs  TRUE  FALSE     57       50        50
# 5792     same_pairs  TRUE  FALSE     57       50        50
# 5793     same_pairs  TRUE  FALSE     57       50        50
# 5794     same_pairs  TRUE  FALSE     57       50        50
# 5795     same_pairs  TRUE  FALSE     57       50        50
# 5796     same_pairs  TRUE  FALSE     57       50        50
# 5797     same_pairs  TRUE  FALSE     57       50        50
# 5798     same_pairs  TRUE  FALSE     57       50        50
# 5799     same_pairs  TRUE  FALSE     57       50        50
# 5800     diff_pairs  TRUE  FALSE     58       50        50
# 5801     diff_pairs  TRUE  FALSE     58       50        50
# 5802     diff_pairs  TRUE  FALSE     58       50        50
# 5803     diff_pairs  TRUE  FALSE     58       50        50
# 5804     diff_pairs  TRUE  FALSE     58       50        50
# 5805     diff_pairs  TRUE  FALSE     58       50        50
# 5806     diff_pairs  TRUE  FALSE     58       50        50
# 5807     diff_pairs  TRUE  FALSE     58       50        50
# 5808     diff_pairs  TRUE  FALSE     58       50        50
# 5809     diff_pairs  TRUE  FALSE     58       50        50
# 5810     diff_pairs  TRUE   TRUE     58       50        50
# 5811     diff_pairs  TRUE  FALSE     58       50        50
# 5812     diff_pairs  TRUE  FALSE     58       50        50
# 5813     diff_pairs  TRUE   TRUE     58       50        50
# 5814     diff_pairs  TRUE   TRUE     58       50        50
# 5815     diff_pairs  TRUE  FALSE     58       50        50
# 5816     diff_pairs  TRUE   TRUE     58       50        50
# 5817     diff_pairs  TRUE   TRUE     58       50        50
# 5818     diff_pairs  TRUE   TRUE     58       50        50
# 5819     diff_pairs  TRUE   TRUE     58       50        50
# 5820     diff_pairs  TRUE   TRUE     58       50        50
# 5821     diff_pairs  TRUE   TRUE     58       50        50
# 5822     diff_pairs  TRUE   TRUE     58       50        50
# 5823     diff_pairs  TRUE   TRUE     58       50        50
# 5824     diff_pairs  TRUE  FALSE     58       50        50
# 5825  high_ps_pairs  TRUE  FALSE     58       50        50
# 5826  high_ps_pairs  TRUE  FALSE     58       50        50
# 5827  high_ps_pairs  TRUE  FALSE     58       50        50
# 5828  high_ps_pairs  TRUE  FALSE     58       50        50
# 5829  high_ps_pairs  TRUE  FALSE     58       50        50
# 5830  high_ps_pairs  TRUE  FALSE     58       50        50
# 5831  high_ps_pairs  TRUE  FALSE     58       50        50
# 5832  high_ps_pairs  TRUE  FALSE     58       50        50
# 5833  high_ps_pairs  TRUE  FALSE     58       50        50
# 5834  high_ps_pairs  TRUE  FALSE     58       50        50
# 5835  high_ps_pairs  TRUE  FALSE     58       50        50
# 5836  high_ps_pairs  TRUE  FALSE     58       50        50
# 5837  high_ps_pairs  TRUE  FALSE     58       50        50
# 5838  high_ps_pairs  TRUE  FALSE     58       50        50
# 5839  high_ps_pairs  TRUE  FALSE     58       50        50
# 5840  high_ps_pairs  TRUE  FALSE     58       50        50
# 5841  high_ps_pairs  TRUE  FALSE     58       50        50
# 5842  high_ps_pairs  TRUE  FALSE     58       50        50
# 5843  high_ps_pairs  TRUE  FALSE     58       50        50
# 5844  high_ps_pairs  TRUE  FALSE     58       50        50
# 5845  high_ps_pairs  TRUE  FALSE     58       50        50
# 5846  high_ps_pairs  TRUE  FALSE     58       50        50
# 5847  high_ps_pairs  TRUE  FALSE     58       50        50
# 5848  high_ps_pairs  TRUE  FALSE     58       50        50
# 5849  high_ps_pairs  TRUE  FALSE     58       50        50
# 5850   low_ps_pairs  TRUE  FALSE     58       50        50
# 5851   low_ps_pairs  TRUE  FALSE     58       50        50
# 5852   low_ps_pairs  TRUE  FALSE     58       50        50
# 5853   low_ps_pairs  TRUE  FALSE     58       50        50
# 5854   low_ps_pairs  TRUE  FALSE     58       50        50
# 5855   low_ps_pairs  TRUE  FALSE     58       50        50
# 5856   low_ps_pairs  TRUE  FALSE     58       50        50
# 5857   low_ps_pairs  TRUE  FALSE     58       50        50
# 5858   low_ps_pairs  TRUE  FALSE     58       50        50
# 5859   low_ps_pairs  TRUE  FALSE     58       50        50
# 5860   low_ps_pairs  TRUE  FALSE     58       50        50
# 5861   low_ps_pairs  TRUE  FALSE     58       50        50
# 5862   low_ps_pairs  TRUE  FALSE     58       50        50
# 5863   low_ps_pairs  TRUE  FALSE     58       50        50
# 5864   low_ps_pairs  TRUE  FALSE     58       50        50
# 5865   low_ps_pairs  TRUE  FALSE     58       50        50
# 5866   low_ps_pairs  TRUE  FALSE     58       50        50
# 5867   low_ps_pairs  TRUE  FALSE     58       50        50
# 5868   low_ps_pairs  TRUE  FALSE     58       50        50
# 5869   low_ps_pairs  TRUE  FALSE     58       50        50
# 5870   low_ps_pairs  TRUE  FALSE     58       50        50
# 5871   low_ps_pairs  TRUE  FALSE     58       50        50
# 5872   low_ps_pairs  TRUE  FALSE     58       50        50
# 5873   low_ps_pairs  TRUE  FALSE     58       50        50
# 5874   low_ps_pairs  TRUE  FALSE     58       50        50
# 5875     same_pairs  TRUE  FALSE     58       50        50
# 5876     same_pairs  TRUE  FALSE     58       50        50
# 5877     same_pairs  TRUE  FALSE     58       50        50
# 5878     same_pairs  TRUE  FALSE     58       50        50
# 5879     same_pairs  TRUE  FALSE     58       50        50
# 5880     same_pairs  TRUE  FALSE     58       50        50
# 5881     same_pairs  TRUE  FALSE     58       50        50
# 5882     same_pairs  TRUE  FALSE     58       50        50
# 5883     same_pairs  TRUE  FALSE     58       50        50
# 5884     same_pairs  TRUE  FALSE     58       50        50
# 5885     same_pairs  TRUE  FALSE     58       50        50
# 5886     same_pairs  TRUE  FALSE     58       50        50
# 5887     same_pairs  TRUE  FALSE     58       50        50
# 5888     same_pairs  TRUE  FALSE     58       50        50
# 5889     same_pairs  TRUE  FALSE     58       50        50
# 5890     same_pairs  TRUE  FALSE     58       50        50
# 5891     same_pairs  TRUE  FALSE     58       50        50
# 5892     same_pairs  TRUE  FALSE     58       50        50
# 5893     same_pairs  TRUE  FALSE     58       50        50
# 5894     same_pairs  TRUE  FALSE     58       50        50
# 5895     same_pairs  TRUE  FALSE     58       50        50
# 5896     same_pairs  TRUE  FALSE     58       50        50
# 5897     same_pairs  TRUE  FALSE     58       50        50
# 5898     same_pairs  TRUE  FALSE     58       50        50
# 5899     same_pairs  TRUE  FALSE     58       50        50
# 5900     diff_pairs  TRUE  FALSE     59       50        50
# 5901     diff_pairs  TRUE  FALSE     59       50        50
# 5902     diff_pairs  TRUE  FALSE     59       50        50
# 5903     diff_pairs  TRUE  FALSE     59       50        50
# 5904     diff_pairs  TRUE  FALSE     59       50        50
# 5905     diff_pairs  TRUE  FALSE     59       50        50
# 5906     diff_pairs  TRUE  FALSE     59       50        50
# 5907     diff_pairs  TRUE  FALSE     59       50        50
# 5908     diff_pairs  TRUE  FALSE     59       50        50
# 5909     diff_pairs  TRUE  FALSE     59       50        50
# 5910     diff_pairs  TRUE   TRUE     59       50        50
# 5911     diff_pairs  TRUE  FALSE     59       50        50
# 5912     diff_pairs  TRUE  FALSE     59       50        50
# 5913     diff_pairs  TRUE   TRUE     59       50        50
# 5914     diff_pairs  TRUE   TRUE     59       50        50
# 5915     diff_pairs  TRUE  FALSE     59       50        50
# 5916     diff_pairs  TRUE   TRUE     59       50        50
# 5917     diff_pairs  TRUE   TRUE     59       50        50
# 5918     diff_pairs  TRUE   TRUE     59       50        50
# 5919     diff_pairs  TRUE   TRUE     59       50        50
# 5920     diff_pairs  TRUE   TRUE     59       50        50
# 5921     diff_pairs  TRUE   TRUE     59       50        50
# 5922     diff_pairs  TRUE   TRUE     59       50        50
# 5923     diff_pairs  TRUE   TRUE     59       50        50
# 5924     diff_pairs  TRUE  FALSE     59       50        50
# 5925  high_ps_pairs  TRUE  FALSE     59       50        50
# 5926  high_ps_pairs  TRUE  FALSE     59       50        50
# 5927  high_ps_pairs  TRUE  FALSE     59       50        50
# 5928  high_ps_pairs  TRUE  FALSE     59       50        50
# 5929  high_ps_pairs  TRUE  FALSE     59       50        50
# 5930  high_ps_pairs  TRUE  FALSE     59       50        50
# 5931  high_ps_pairs  TRUE  FALSE     59       50        50
# 5932  high_ps_pairs  TRUE  FALSE     59       50        50
# 5933  high_ps_pairs  TRUE  FALSE     59       50        50
# 5934  high_ps_pairs  TRUE  FALSE     59       50        50
# 5935  high_ps_pairs  TRUE  FALSE     59       50        50
# 5936  high_ps_pairs  TRUE  FALSE     59       50        50
# 5937  high_ps_pairs  TRUE  FALSE     59       50        50
# 5938  high_ps_pairs  TRUE  FALSE     59       50        50
# 5939  high_ps_pairs  TRUE  FALSE     59       50        50
# 5940  high_ps_pairs  TRUE  FALSE     59       50        50
# 5941  high_ps_pairs  TRUE  FALSE     59       50        50
# 5942  high_ps_pairs  TRUE  FALSE     59       50        50
# 5943  high_ps_pairs  TRUE  FALSE     59       50        50
# 5944  high_ps_pairs  TRUE  FALSE     59       50        50
# 5945  high_ps_pairs  TRUE  FALSE     59       50        50
# 5946  high_ps_pairs  TRUE  FALSE     59       50        50
# 5947  high_ps_pairs  TRUE  FALSE     59       50        50
# 5948  high_ps_pairs  TRUE  FALSE     59       50        50
# 5949  high_ps_pairs  TRUE  FALSE     59       50        50
# 5950   low_ps_pairs  TRUE  FALSE     59       50        50
# 5951   low_ps_pairs  TRUE  FALSE     59       50        50
# 5952   low_ps_pairs  TRUE  FALSE     59       50        50
# 5953   low_ps_pairs  TRUE  FALSE     59       50        50
# 5954   low_ps_pairs  TRUE  FALSE     59       50        50
# 5955   low_ps_pairs  TRUE  FALSE     59       50        50
# 5956   low_ps_pairs  TRUE  FALSE     59       50        50
# 5957   low_ps_pairs  TRUE  FALSE     59       50        50
# 5958   low_ps_pairs  TRUE  FALSE     59       50        50
# 5959   low_ps_pairs  TRUE  FALSE     59       50        50
# 5960   low_ps_pairs  TRUE  FALSE     59       50        50
# 5961   low_ps_pairs  TRUE  FALSE     59       50        50
# 5962   low_ps_pairs  TRUE  FALSE     59       50        50
# 5963   low_ps_pairs  TRUE  FALSE     59       50        50
# 5964   low_ps_pairs  TRUE  FALSE     59       50        50
# 5965   low_ps_pairs  TRUE  FALSE     59       50        50
# 5966   low_ps_pairs  TRUE  FALSE     59       50        50
# 5967   low_ps_pairs  TRUE  FALSE     59       50        50
# 5968   low_ps_pairs  TRUE  FALSE     59       50        50
# 5969   low_ps_pairs  TRUE  FALSE     59       50        50
# 5970   low_ps_pairs  TRUE  FALSE     59       50        50
# 5971   low_ps_pairs  TRUE  FALSE     59       50        50
# 5972   low_ps_pairs  TRUE  FALSE     59       50        50
# 5973   low_ps_pairs  TRUE  FALSE     59       50        50
# 5974   low_ps_pairs  TRUE  FALSE     59       50        50
# 5975     same_pairs  TRUE  FALSE     59       50        50
# 5976     same_pairs  TRUE  FALSE     59       50        50
# 5977     same_pairs  TRUE  FALSE     59       50        50
# 5978     same_pairs  TRUE  FALSE     59       50        50
# 5979     same_pairs  TRUE  FALSE     59       50        50
# 5980     same_pairs  TRUE  FALSE     59       50        50
# 5981     same_pairs  TRUE  FALSE     59       50        50
# 5982     same_pairs  TRUE  FALSE     59       50        50
# 5983     same_pairs  TRUE  FALSE     59       50        50
# 5984     same_pairs  TRUE  FALSE     59       50        50
# 5985     same_pairs  TRUE  FALSE     59       50        50
# 5986     same_pairs  TRUE  FALSE     59       50        50
# 5987     same_pairs  TRUE  FALSE     59       50        50
# 5988     same_pairs  TRUE  FALSE     59       50        50
# 5989     same_pairs  TRUE  FALSE     59       50        50
# 5990     same_pairs  TRUE  FALSE     59       50        50
# 5991     same_pairs  TRUE  FALSE     59       50        50
# 5992     same_pairs  TRUE  FALSE     59       50        50
# 5993     same_pairs  TRUE  FALSE     59       50        50
# 5994     same_pairs  TRUE  FALSE     59       50        50
# 5995     same_pairs  TRUE  FALSE     59       50        50
# 5996     same_pairs  TRUE  FALSE     59       50        50
# 5997     same_pairs  TRUE  FALSE     59       50        50
# 5998     same_pairs  TRUE  FALSE     59       50        50
# 5999     same_pairs  TRUE  FALSE     59       50        50

# %%
#     df_cf_normalized[fc7]
    
    
#     for x in df_cf_normalized.drop(columns=['img1', 'img2', 'input', 'conv1', 'conv2', 'conv3', 'conv4', 'conv5', 'fc6','cf', 'hv', 'fc8','type', 'index','num_ids','num_pics']).columns:
#         print(df_cf_normalized.groupby(['index'])[x].reset_index())
#         df_cf_normalized[x]= (df_cf_normalized.groupby(['index'])[x]/cf_max_value[x]) 
#     print(df_cf_normalized)
    
#     #df of size of each type
#     size_df_views = df_views.groupby(['type']).count()
#     sqrt_size_views = np.sqrt(size_df_views)
    
#     #mean of each columns by type of pairs
#     means_df_views = df_views.groupby(['type']).mean()
#     means_df_views = means_df_views.rename_axis("layers", axis="columns")
#     means_df_views = means_df_views.transpose()

    
#     std_views = df_views.groupby(['type']).std()
#     std_views = std_views.transpose()
    
#     #standard error of mean
#     se_views = std_views.transpose().div(sqrt_size_views).transpose()
    
    



#     ##################head views###################
    
#     title = base_title +'_views_'+add_to_title

#     #change frontal-ref to frontal_ref
#     df['type'] = df['type'].replace(['frontal-ref'],'frontal_ref')


#     #change frontal-quarter_left to frontal_quarter_left
#     df['type'] = df['type'].replace(['frontal-quarter_left'],'frontal_quarter_left')


#     #change frontal-half_left to frontal_half_left
#     df['type'] = df['type'].replace(['frontal-half_left'],'frontal_half_left')

#     #remove  HPS,LPS,SAME type.
#     # df = df[df.type.str.contains("same_pairs|frontal|diff_pairs")]
#     df1 = df[df.type.str.contains("frontal|diff_pairs")]

#     df2 = df1[df1.type.str.contains("same_pairs|diff_pairs")]
#     # df1 = df[df['type'] =='diff_pairs'|df['type']=='same_pairs']
#     df3 = df2[df2.img1.str.contains("CM")] 
#     # df3 = df[df['type'] !='diff_pairs'&df['type'] !='same_pairs']
#     df4 = df1[~df1.type.str.contains("same_pairs|diff_pairs")]

#     df_views = pd.concat([df3,df4])
#     df_views.reset_index()
#     max_value_df = df_views.max()
#     max_value_df
#     df_views = df_views.reset_index(drop=True)
    
#     df_views = df_views.drop(columns=['img1', 'img2'])
#     normalized_threshold_views = threshold37/max_value_df['fc7']
    
#     for x in df_views.drop(columns=['type']).columns:
#         df_views[x]= (df_views[x]/df_views[x].max()) 
    
#     #df of size of each type
#     size_df_views = df_views.groupby(['type']).count()
#     sqrt_size_views = np.sqrt(size_df_views)
    
#     #mean of each columns by type of pairs
#     means_df_views = df_views.groupby(['type']).mean()
#     means_df_views = means_df_views.rename_axis("layers", axis="columns")
#     means_df_views = means_df_views.transpose()

    
#     std_views = df_views.groupby(['type']).std()
#     std_views = std_views.transpose()
    
#     #standard error of mean
#     se_views = std_views.transpose().div(sqrt_size_views).transpose()
    
#     #combine means and std df to one:
#     columns = means_df_views.columns.copy()
#     rows =  means_df_views.index.copy()
#     header = pd.MultiIndex.from_product([columns,
#                                          ['mean','STD']],
#                                         names=['type','mean/STD'])
#     df_means_std = pd.DataFrame( 
#                       index=rows, 
#                       columns=header)

#     df_means_std[('diff_pairs','mean')] = means_df_views.diff_pairs.copy()
#     df_means_std[('diff_pairs','STD')] = std_views.diff_pairs.copy()
    
#     df_means_std[('frontal_half_left','mean')] = means_df_views.frontal_half_left.copy()
#     df_means_std[('frontal_half_left','STD')] = std_views.frontal_half_left.copy()
    
#     df_means_std[('frontal_quarter_left','mean')] = means_df_views.frontal_quarter_left.copy()
#     df_means_std[('frontal_quarter_left','STD')] = std_views.frontal_quarter_left.copy()
    
#     df_means_std[('frontal_ref','mean')] = means_df_views.frontal_ref.copy()
#     df_means_std[('frontal_ref','STD')] = std_views.frontal_ref.copy()
    
    
    
#     #save to csv/excel

#     if (save_views_csv == 1):

#         excel_book = mean_std_folder+add_to_title+'/'+excel_title+'.xlsx'
#         sheet = title+'_mean_std'
#         if  os.path.exists(excel_book):
#             with pd.ExcelWriter(excel_book, engine='openpyxl', mode='a') as writer:  
#                 df_means_std.to_excel(writer, sheet_name=sheet)

#         else:
#             with pd.ExcelWriter(excel_book) as writer:  
#                 df_means_std.to_excel(writer, sheet_name=sheet)
#     if (save_mean_views_csv == 1):
#         excel_book = mean_folder_views+add_to_title+'/'+excel_title+'.xlsx'
#         sheet = title+'_mean'
#         if  os.path.exists(excel_book):
#             with pd.ExcelWriter(excel_book, engine='openpyxl', mode='a') as writer:  
#                 means_df_views.to_excel(writer, sheet_name=sheet)

#         else:
#             with pd.ExcelWriter(excel_book) as writer:  
#                 means_df_views.to_excel(writer, sheet_name=sheet)
                
#     if (save_std_views_csv == 1):
#         excel_book = std_folder_views+add_to_title+'/'+excel_title+'.xlsx'
#         sheet = title+'_std'
#         if  os.path.exists(excel_book):
#             with pd.ExcelWriter(excel_book, engine='openpyxl', mode='a') as writer:  
#                 std_views.to_excel(writer, sheet_name=sheet)

#         else:
#             with pd.ExcelWriter(excel_book) as writer:  
#                 std_views.to_excel(writer, sheet_name=sheet)
    
#     if (save_se_views_csv == 1):
#         excel_book = se_folder_views+add_to_title+'/'+excel_title+'.xlsx'
#         sheet = title+'_se'
#         if  os.path.exists(excel_book):
#             with pd.ExcelWriter(excel_book, engine='openpyxl', mode='a') as writer:  
#                 se_views.to_excel(writer, sheet_name=sheet)

#         else:
#             with pd.ExcelWriter(excel_book) as writer:  
#                 se_views.to_excel(writer, sheet_name=sheet)
    


    
# #     #plot
# #     plot = means_df_views.plot(**plot_kwargs, title = title, ylim = [0,1], lw=4)
# #     plt.scatter(7, normalized_treshold_views, color='black')

#     #plot
#     #with std bars
# #     score_lower_limit1 = means_df_views - std_views
# #     score_upper_limit1 = means_df_views + std_views
#     #with SE bars
#     score_lower_limit1 = means_df_views - se_views
#     score_upper_limit1 = means_df_views + se_views
#     COLORS = "blue", "yellow", "green", "red"
    
#     param_fig1, param_ax1 = plt.subplots(sharex = 'all', figsize=(20,10))
#     plt.ylim(0, 1)
#     param_ax1.set_title(title)

#     param_ax1.plot(means_df_views, marker='.', lw=4)
#     plt.legend( ['diff_pairs', 'frontal_half_left','frontal_quarter_left','frontal_ref'])#?????



#     for i, col in enumerate(means_df_views.columns):
#             param_ax1.fill_between(means_df_views.index,
#                               score_lower_limit1[col],
#                               score_upper_limit1[col],
#                               color=COLORS[i],
#                               alpha=0.1)
#     param_ax1.scatter(7, normalized_threshold_views, color='black')
#     matplotlib.rcParams.update({'font.size': 20})
# #     plt.rcParams["font.family"] = "Humor Sans"

    
#     #save plot
#     if (save_views_plot==1):
#         plt.savefig(plots_folder+'/head_views/'+title)
    



    
#     #################critical features#################
#     title = base_title +'_cf_'+add_to_title
    
#     #remove all last rows - save only DIFF,HPS,LPS,SAME type.
#     df_cf = df[~df.type.str.contains("frontal")]
    
#     #max values df
#     max_value_df = df_cf.max()
    
#     df_cf = df_cf.reset_index(drop=True)
#     df_cf = df_cf.drop(columns=['img1', 'img2'])
    
#     #normalized threshold
#     normalized_threshold_cf = threshold37/max_value_df['fc7']
    
#     #
#     for x in df_cf.drop(columns=['type']).columns:
#         df_cf[x]= (df_cf[x]/df_cf[x].max()) 
    
#     #df of size of each type
#     size_df_cf = df_cf.groupby(['type']).count()
#     sqrt_size_cf = np.sqrt(size_df_cf)
    
#     #mean of each columns by type of pairs
#     means_df_cf = df_cf.groupby(['type']).mean()
#     means_df_cf = means_df_cf.rename_axis("layers", axis="columns")
#     means_df_cf = means_df_cf.transpose()
    
#     #standard deviation
#     std_cf = df_cf.groupby(['type']).std()
#     std_cf = std_cf.transpose()
    
#     #standard error of mean
#     se_cf = std_cf.transpose().div(sqrt_size_cf).transpose()
    
#     #combine means and std df to one:
#     columns_cf = means_df_cf.columns.copy()
#     rows_cf =  means_df_cf.index.copy()
#     header_cf = pd.MultiIndex.from_product([columns_cf,
#                                          ['mean','STD']],
#                                         names=['type','mean/STD'])
#     df_means_std_cf = pd.DataFrame( 
#                       index=rows_cf, 
#                       columns=header_cf)

#     df_means_std_cf[('diff_pairs','mean')] = means_df_cf.diff_pairs.copy()
#     df_means_std_cf[('diff_pairs','STD')] = std_cf.diff_pairs.copy()
    
#     df_means_std_cf[('high_ps_pairs','mean')] = means_df_cf.high_ps_pairs.copy()
#     df_means_std_cf[('high_ps_pairs','STD')] = std_cf.high_ps_pairs.copy()
    
#     df_means_std_cf[('low_ps_pairs','mean')] = means_df_cf.low_ps_pairs.copy()
#     df_means_std_cf[('low_ps_pairs','STD')] = std_cf.low_ps_pairs.copy()
    
#     df_means_std_cf[('same_pairs','mean')] = means_df_cf.same_pairs.copy()
#     df_means_std_cf[('same_pairs','STD')] = std_cf.same_pairs.copy()
    
    
#     #save to csv/excel
    
#     if (save_cf_csv == 1):

#         excel_book = mean_std_folder+add_to_title+'/'+excel_title+'.xlsx'
#         sheet = title+'_mean_std'
#         if  os.path.exists(excel_book):
#             with pd.ExcelWriter(excel_book, engine='openpyxl', mode='a') as writer:  
#                 df_means_std_cf.to_excel(writer, sheet_name=sheet)

#         else:
#             with pd.ExcelWriter(excel_book) as writer:  
#                 df_means_std_cf.to_excel(writer, sheet_name=sheet)
#     if (save_mean_cf_csv == 1):
#         excel_book = mean_folder_cf+add_to_title+'/'+excel_title+'.xlsx'
#         sheet = title+'_mean'
#         if  os.path.exists(excel_book):
#             with pd.ExcelWriter(excel_book, engine='openpyxl', mode='a') as writer:  
#                 means_df_cf.to_excel(writer, sheet_name=sheet)

#         else:
#             with pd.ExcelWriter(excel_book) as writer:  
#                 means_df_cf.to_excel(writer, sheet_name=sheet)

#     if (save_std_cf_csv == 1):
#         excel_book = std_folder_cf+add_to_title+'/'+excel_title+'.xlsx'
#         sheet = title+'_std'
#         if  os.path.exists(excel_book):
#             with pd.ExcelWriter(excel_book, engine='openpyxl', mode='a') as writer:  
#                 std_cf.to_excel(writer, sheet_name=sheet)

#         else:
#             with pd.ExcelWriter(excel_book) as writer:  
#                 std_cf.to_excel(writer, sheet_name=sheet)
                
#     if (save_se_cf_csv == 1):
#         excel_book = se_folder_cf+add_to_title+'/'+excel_title+'.xlsx'
#         sheet = title+'_se'
#         if  os.path.exists(excel_book):
#             with pd.ExcelWriter(excel_book, engine='openpyxl', mode='a') as writer:  
#                 se_cf.to_excel(writer, sheet_name=sheet)

#         else:
#             with pd.ExcelWriter(excel_book) as writer:  
#                 se_cf.to_excel(writer, sheet_name=sheet)


    
    
    
# #     if (save_cf_csv == 1):
# #         df_means_std_cf.to_csv(mean_std_folder+title+'_mean_std')
# #         # df.to_excel("output.xlsx", sheet_name='Sheet_name_1')  
# #     if (save_mean_cf_csv == 1):
# # #         means_df_cf.to_csv(mean_folder+'/mean/'+title+'_mean')
# #     # df.to_excel("output.xlsx", sheet_name='Sheet_name_1') 
# #         means_df_cf.to_excel(mean_folder+'mean/'+add_to_title+'/'+excel_title+'.xlsx', sheet_name=title+'_mean') 

# #     if (save_std_cf_csv == 1):
# #         std_cf.to_csv(std_folder+'/std/'+title+'_std')
# #     # df.to_excel("output.xlsx", sheet_name='Sheet_name_1') 

#     #plot
#     score_lower_limit = means_df_cf - se_cf
#     score_upper_limit = means_df_cf + se_cf
#     COLORS = "blue", "yellow", "green", "red"
    
#     param_fig, param_ax = plt.subplots(sharex = 'all', figsize=(20,10))
#     plt.ylim(0, 1)
#     param_ax.set_title(title)

#     param_ax.plot(means_df_cf, marker='.', lw=4)
#     plt.legend( ['diff_pairs', 'high_ps_pairs','low_ps_pairs','same_pairs'])#?????


    
    
# #     arr1 =param_ax.plot(means_df_cf.diff_pairs, marker='*', lw=4, label = 'diff_pairs')
# #     arr2 = param_ax.plot(means_df_cf.high_ps_pairs, marker='*', lw=4, label = 'hps')
# #     arr3 = param_ax.plot(means_df_cf.low_ps_pairs, marker='*', lw=4, label = 'lps')
# #     arr4 =param_ax.plot(means_df_cf.same_pairs, marker='*', lw=4, label = 'same')
# #     plt.legend([arr1, arr2, arr3, arr4], ['diff_pairs','high_ps_pairs','low_ps_pairs','same_pairs'])
# #     plot = means_df_cf.plot(**plot_kwargs, title = title, ylim = [0,1], lw=4)





#     for i, col in enumerate(means_df_cf.columns):
#             param_ax.fill_between(means_df_cf.index,
#                               score_lower_limit[col],
#                               score_upper_limit[col],
#                               color=COLORS[i],
#                               alpha=0.1)
#     param_ax.scatter(7, normalized_threshold_cf, color='black')
#     matplotlib.rcParams.update({'font.size': 20})
# #     plt.rcParams["font.family"] = "Humor Sans"


        

#     #save plot
#     if (save_cf_plot==1):
#         plt.savefig(plots_folder+'/cf/'+title)
