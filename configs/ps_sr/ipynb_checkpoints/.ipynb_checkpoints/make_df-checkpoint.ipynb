# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os


path = "/home/hdd_storage/MR/results/asians"
suffix = "/vgg16/results/mandy_run/mat_dom/mat_dom_fc7.csv"
folder_prefix = "small_ids_no_asians_"
results_path = "/home/mandy/project/facial_feature_impact_comparison/configs/ps_sr/large_results"
run_num = 1
# num_ids = [2,5,10,50,100]
num_pics = [1,5,10,20,50,100,200,300]
num_ids = [200,500,960]
# num_pics = [300]

# pd.set_option('display.max_rows', df.shape[0]+1)

# %%
    for ids in num_ids:
        id_path = os.path.join(path,str(ids) +'_ids' )
        for image in num_pics:
            folder_suffix = str(ids) +'_ids_' + str(ids) +'_'+ str(image) 

    #      "run on all indexes in id and image"
            for index in range(run_num):
                folder_last = folder_suffix + '_' + str(index)
                folder_name = folder_prefix+ folder_last 
                full_path_to_folder = os.path.join(id_path, folder_name)
                full_path_fc7 =full_path_to_folder+ suffix

                if index ==0 :
                    # data = np.recfromcsv(full_path_fc7, delimiter=',', filling_values=np.nan, case_sensitive=True, deletechars='', replace_space=' ')
                    # print(data)


#                     #reset addition - first df
#                     with open(full_path_fc7,'r') as dest_f:
#                         data_iter = csv.reader(dest_f,
#                                             delimiter = ',',
#                                             quotechar = "'")
#                         data = [data for data in data_iter]
#                     data_array = np.asarray(data).size
#                     # print('data_array: \n',data_array)
# #                     print(data_array)


                    # # from numpy import genfromtxt
                    # my_data = np.genfromtxt(full_path_fc7, delimiter=',', dtype = None)
                    # print('my_data: \n',my_data)


                    origin_df = pd.read_csv(full_path_fc7, header=0)
#                     print('origin_df: ',origin_df)
#                     origin_df = origin_df.set_index('Unnamed: 0')
                    origin_df_no_str = origin_df.loc[:, origin_df.columns != 'Unnamed: 0']

#                     origin_df_no_str = origin_df[0:,1:]
                    print('origin_df_no_str should be equal: ',origin_df_no_str.shape)
#                     print('origin_df_no_str: \n', origin_df_no_str)
#                     print(origin_df[['Unnamed: 0']].to_string(index=False)) 
#                     origin_df = origin_df.set_index("Unnamed: 0")
#                     print('origin_df after set index: ',origin_df)

                    #tamar_08.jpg.1
                    # print('origin_df last col: ',origin_df.columns[153])
                    #extract first column:
                    first_col = origin_df.iloc[:,0]
                    # extract first row:
                    first_row = origin_df.columns#.iloc[0]
                    # first_row = origin_df.index.tolist()
#                     print(type(first_row))
                    print('first_col: ', first_row.tolist())
                    print(f'shape is before else: {origin_df_no_str.shape}')
                    print(f'origin: {origin_df_no_str}')

                else: # addition for all 29 df
                    #read csv as df
                    df_to_add = pd.read_csv(full_path_fc7)
                    df_to_add = df_to_add.loc[:, df_to_add.columns != 'Unnamed: 0']
                    print('df_to_add should be equal: ',df_to_add.shape)
                    print('df_to_add: ',df_to_add)

                    

#                     print(f'shape is before add: {origin_df.shape}')

                    #addition
                    origin_df = origin_df_no_str.add(df_to_add)
                    print(f'shape is df_to_add: {df_to_add.shape}')
                    print(f'shape is else: {origin_df.shape}')
                    print(f'after addition: {origin_df}')

                    #average     
            print('got here')
            origin_df = origin_df.div(run_num)
            print(f'after average average: {origin_df}')
            print(f'shape is average: {origin_df.shape}')
            
            #add first column back
#             origin_df.insert(0, 'Name', first_col)
#             origin_df = origin_df.set_index( 'Name')

#           "save average fc7 for id and image, with id and image in name"
            result_path = os.path.join(results_path, folder_suffix+'.csv')
            print(f'saved to {result_path}')
            print(f'shape is : {origin_df.shape}')
            origin_df.to_csv(result_path)
#
# Out:
# origin_df_no_str should be equal:  (156, 156)
# first_col:  ['Unnamed: 0', 'omer_02.jpg', 'tal_05.jpg', 'omer_07.jpg', 'tal_06.jpg', 'omer_06.jpg', 'omer_08.jpg', 'tal_01.jpg', 'omer_03.jpg', 'tal_07.jpg', 'tal_03.jpg', 'omer_04.jpg', 'omer_10.jpg', 'tal_09.jpg', 'tal_02.jpg', 'tal_08.jpg', 'omer_09.jpg', 'tal_10.jpg', 'omer_05.jpg', 'tal_04.jpg', 'matt_04.jpg', 'dom_10.jpg', 'dom_05.jpg', 'matt_08.jpg', 'dom_04.jpg', 'matt_02.jpg', 'matt_07.jpg', 'matt_06.jpg', 'matt_05.jpg', 'dom_07.jpg', 'dom_03.jpg', 'matt_03.jpg', 'matt_01.jpg', 'dom_06.jpg', 'matt_10.jpg', 'dom_01.jpg', 'dom_09.jpg', 'matt_09.jpg', 'dom_02.jpg', 'tess_03.jpg', 'taz_06.jpg', 'taz_04.jpg', 'taz_03.jpg', 'tess_01.jpg', 'tess_07.jpg', 'tess_05.jpg', 'taz_05.jpg', 'tess_02.jpg', 'tess_09.jpg', 'tess_06.jpg', 'taz_07.jpg', 'taz_02.jpg', 'tess_04.jpg', 'taz_09.jpg', 'tess_08.jpg', 'taz_08.jpg', 'taz_01.jpg', 'tess_10.jpg', 'taz_10.jpg', 'marina_07.jpg', 'tamar_04.jpg', 'tess_03.jpg.1', 'omer_02.jpg.1', 'marina_04.jpg', 'taz_06.jpg.1', 'taz_04.jpg.1', 'marina_01.jpg', 'matt_04.jpg.1', 'taz_03.jpg.1', 'dom_10.jpg.1', 'dom_05.jpg.1', 'tess_01.jpg.1', 'tal_05.jpg.1', 'marina_06.jpg', 'tamar_09.jpg', 'omer_07.jpg.1', 'tal_06.jpg.1', 'tess_07.jpg.1', 'matt_08.jpg.1', 'marina_08.jpg', 'omer_06.jpg.1', 'omer_08.jpg.1', 'tal_01.jpg.1', 'dom_04.jpg.1', 'tamar_10.jpg', 'omer_03.jpg.1', 'tamar_02.jpg', 'tamar_05.jpg', 'tal_07.jpg.1', 'tess_05.jpg.1', 'matt_02.jpg.1', 'tamar_07.jpg', 'tamar_03.jpg', 'tal_03.jpg.1', 'taz_05.jpg.1', 'marina_09.jpg', 't
# ..           ...         ...          ...         ...         ...  ...
# 151     0.470901    0.396803     0.117828    0.434112    0.554219  ...
# 152     0.704103    0.178398     0.316391    0.354337    0.536251  ...
# 153     0.524798    0.543376     0.327927    0.300410    0.563687  ...
# 154     0.500019    0.152763     0.384719    0.435498    0.555084  ...
# 155     0.650387    0.269266     0.275517    0.318984    0.541643  ...
#
#      tamar_07.jpg.1  tamar_03.jpg.1  marina_09.jpg.1  tamar_01.jpg.1  \
# 0          0.193683        0.149838         0.624883        0.166833
# 1          0.171391        0.099874         0.588126        0.151377
# 2          0.243126        0.254654         0.599255        0.213267
# 3          0.108477        0.209456         0.243272        0.160339
# 4          0.415615        0.520508         0.312725        0.485554
# ..              ...             ...              ...             ...
# 151        0.065203        0.119037         0.381640        0.074612
# 152        0.273225        0.377518         0.262164        0.349629
# 153        0.136247        0.068828         0.578253        0.113366
# 154        0.507370        0.590302         0.025411        0.571178
# 155        0.146592        0.200681         0.360306        0.198615
#
#      marina_10.jpg.1  tamar_06.jpg.1  marina_05.jpg.1  marina_02.jpg.1  \
# 0           0.576273        0.290738         0.405101     1.181868e-01
# 1           0.526773        0.272575         0.353287     4.654366e-02
# 2           0.642346        0.229714         0.533149     3.310878e-01
# 3           0.359132        0.064384         0.258606     3.161252e-01
# 4           0.102175        0.462714         0.118111     4.723397e-01
# ..               ...             ...              ...              ...
# 151         0.491568        0.000000         0.362154     2.421084e-01
# 152         0.061274        0.362154         0.000000     3.304864e-01
# 153         0.509365        0.242108         0.330486     1.192093e-07
# 154         0.214514        0.444758         0.288987     6.188964e-01
# 155         0.206810        0.262778         0.068798     1.506633e-01
#
#      marina_03.jpg.1  tamar_08.jpg.1
# 0       6.495748e-01    2.556046e-01
# 1       6.238416e-01    1.917936e-01
# 2       6.198366e-01    4.390773e-01
# 3       3.058891e-01    2.148343e-01
# 4       3.148867e-01    2.332224e-01
# ..               ...             ...
# 151     4.447581e-01    2.627777e-01
# 152     2.889874e-01    6.879795e-02
# 153     6.188964e-01    1.506633e-01
# 154     5.960464e-08    3.996386e-01
# 155     3.996386e-01    5.960464e-08
#
# [156 rows x 156 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.conda/envs/mr/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~/.conda/envs/mr/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~/.conda/envs/mr/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-2dc0cf39d813> in <module>
#      74
#      75                 #average
# ---> 76         origin_df = origin_df.div(run_num)
#      77         print(f'after average average: {origin_df}')
#      78         print(f'shape is average: {origin_df.shape}')
#
# ~/.conda/envs/mr/lib/python3.8/site-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#     658                 self = self.fillna(fill_value)
#     659
# --> 660             new_data = dispatch_to_series(self, other, op)
#     661
#     662         return self._construct_result(new_data)
#
# ~/.conda/envs/mr/lib/python3.8/site-packages/pandas/core/ops/__init__.py in dispatch_to_series(left, right, func, axis)
#     263     if not is_list_like(right):
#     264         # i.e. scalar, faster than checking np.ndim(right) == 0
# --> 265         bm = left._mgr.apply(array_op, right=right)
#     266         return type(left)(bm)
#     267
#
# ~/.conda/envs/mr/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     402
#     403             if callable(f):
# --> 404                 applied = b.apply(f, **kwargs)
#     405             else:
#     406                 applied = getattr(b, f)(**kwargs)
#
# ~/.conda/envs/mr/lib/python3.8/site-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     344         """
#     345         with np.errstate(all="ignore"):
# --> 346             result = func(self.values, **kwargs)
#     347
#     348         return self._split_op_result(result)
#
# ~/.conda/envs/mr/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     188     else:
#     189         with np.errstate(all="ignore"):
# --> 190             res_values = na_arithmetic_op(lvalues, rvalues, op)
#     191
#     192     return res_values
#
# ~/.conda/envs/mr/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     148             #  will handle complex numbers incorrectly, see GH#32047
#     149             raise
# --> 150         result = masked_arith_op(left, right, op)
#     151
#     152     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# ~/.conda/envs/mr/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in masked_arith_op(x, y, op)
#     110         if mask.any():
#     111             with np.errstate(all="ignore"):
# --> 112                 result[mask] = op(xrav[mask], y)
#     113
#     114     result, _ = maybe_upcast_putmask(result, ~mask, np.nan)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
